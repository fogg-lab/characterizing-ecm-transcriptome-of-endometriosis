# %%
library(tidyverse)

# Custom package
library(rutils)
# Out:
# -- Attaching packages ---------------------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.0.6     v dplyr   1.0.4
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ------------------------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
# ip <- as.data.frame(installed.packages()[,c(1,3:4)])
# rownames(ip) <- NULL
# ip <- ip[is.na(ip$Priority),1:2,drop=FALSE]
# print(ip, row.names=FALSE)

# %%
package_df <- installed.packages() %>%
    as_tibble() %>%
    rename_with(~ tolower(.)) %>%
    filter(!(priority %in% c("base"))) %>%
    select(package, version) %>%
    write_csv()
package_df
# Out:
#        package          version
# 1      AnnotationDbi    1.52.0
# 2      BH               1.75.0-0
# 3      Biobase          2.50.0
# 4      BiocGenerics     0.36.0
# 5      BiocManager      1.30.10
# 6      BiocParallel     1.24.1
# 7      BiocVersion      3.12.0
# 8      DBI              1.1.1
# 9      DESeq2           1.30.0
# 10     DO.db            2.9
# 11     DOSE             3.16.0
# 12     DT               0.17
# 13     DelayedArray     0.16.1
# 14     Formula          1.2-4
# 15     GGally           2.1.1
# 16     GO.db            3.12.1
# 17     GOSemSim         2.16.1
# 18     GenSA            1.1.7
# 19     GenomeInfoDb     1.26.2
# 20     GenomeInfoDbData 1.2.4
# 21     GenomicRanges    1.42.0
# 22     HDF5Array        1.18.1
# 23     Hmisc            4.4-2
# 24     IRanges          2.24.1
# 25     IRdisplay        1.0
# 26     IRkernel         1.1.1
# 27     KMsurv           0.1-5
# 28     KernSmooth       2.23-18
# 29     MASS             7.3-53
# 30     Matrix           1.3-2
# <U+22EE> <U+22EE>         <U+22EE>
# 279    tibble           3.0.6
# 280    tidygraph        1.2.0
# 281    tidyr            1.1.2
# 282    tidyselect       1.1.0
# 283    tidyverse        1.3.0
# 284    timeDate         3043.102
# 285    tinytex          0.29
# 286    triebeard        0.3.0
# 287    tweenr           1.0.1
# 288    umap             0.2.7.0
# 289    urltools         1.7.3
# 290    usethis          2.0.0
# 291    utf8             1.1.4
# 292    uuid             0.1-4
# 293    vctrs            0.3.6
# 294    viridis          0.5.1
# 295    viridisLite      0.3.0
# 296    waldo            0.2.3
# 297    whisker          0.4
# 298    withr            2.4.1
# 299    xfun             0.20
# 300    xml2             1.3.2
# 301    xopen            1.0.0
# 302    xtable           1.8-4
# 303    xts              0.12.1
# 304    yaml             2.2.1
# 305    zeallot          0.1.0
# 306    zip              2.1.1
# 307    zlibbioc         1.36.0
# 308    zoo              1.8-8
