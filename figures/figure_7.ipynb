# %%
library(tidyverse)
library(cowplot)

# Custom package
library(rutils)
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.0.6     v dplyr   1.0.4
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
dirs <- rutils::get_dev_directories(dev_paths_file = "../dev_paths.txt")
unified_dsets <- c("unified_cervical_data", "unified_uterine_data", "unified_uterine_endometrial_data")
projects <- c("CESC", "UCS", "UCEC")

# %%
text_size <- 8
label_text_size <- 8
small_text_size <- 8
family <- "ArialMT"
dpi <- 320
ht <- 6
wd <- 6

# %%
cesc_gran_ea_figs <- load(paste0(dirs$figures_dir, "/saved_obj/", unified_dsets[1], "_granular_ea_plots.RData"))

# %%
cesc_gran_ea_figs
# Out:
# [1] "CESC_umsmg_ea_plot"  "CESC_nsmg_1_ea_plot" "CESC_nsmg_2_ea_plot"
# [4] "CESC_nsmg_3_ea_plot"

# %%
fig7 <- plot_grid(
    CESC_umsmg_ea_plot, CESC_nsmg_1_ea_plot, CESC_nsmg_2_ea_plot, CESC_nsmg_3_ea_plot,
    labels = c("A. Uni/multivariable", "B. Module 1", "C. Module 2", "D. Module 3"),
    label_size = label_text_size,
    label_fontfamily = family,
    nrow = 2
)

# %%
fig7
# Out:
# plot without title

# %%
ggsave(paste0(dirs$figures_dir, "/paneled/figure7.png"), fig7, height = ht, width = wd, dpi = dpi)
