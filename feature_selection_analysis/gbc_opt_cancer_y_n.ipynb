# %%
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import f1_score
from skopt.space import Real, Integer, Categorical
from skopt import gp_minimize

import utils.dev_config as dev_conf
import utils.preprocessing as prep
import utils.optimization as opt

# %%
dirs = dev_conf.get_dev_directories("../dev_paths.txt")
unified_dsets = ["unified_cervical_data", "unified_uterine_data", "unified_uterine_endometrial_data"]

# %%
dset_idx = 0

# %%
seed = 123
rand = np.random.RandomState()

# %%
condition_map = {"healthy": 0, "tumor": 1}

# %% [markdown]
# # Load normalized matrisome count data

# %%
norm_matrisome_counts_df = pd.read_csv(f"{dirs.data_dir}/{unified_dsets[dset_idx]}/norm_matrisome_counts.tsv", sep='\t')
counts_t_df = prep.transpose_df(
    norm_matrisome_counts_df, "geneID", "sample_name"
)
print(counts_t_df.shape)
# norm_filtered_matrisome_counts_t_df.head()
# Out:
# (272, 1009)

# %%
coldata_df = pd.read_csv(f"{dirs.data_dir}/{unified_dsets[dset_idx]}/coldata.tsv", sep="\t")

# %%
joined_df = (
    pd.merge(coldata_df, counts_t_df, on="sample_name")
        .set_index("sample_name")
        .drop("data_source", axis=1)
        .assign(condition = lambda df: df.condition.apply(lambda x: condition_map[x]))
)

# %%
joined_df.condition.value_counts()
# Out:
# 1    259
# 0     13
# Name: condition, dtype: int64

# %% [markdown]
# # Optimize model

# %%
rand.seed(seed)
x_df, y_df = prep.shuffle_data(joined_df, rand)

# %% [markdown]
# ## Get baselines

# %%
rand.seed(seed)

label_value_counts_df = (
    pd.DataFrame(y_df.condition.value_counts()).reset_index()
        .rename(columns={"index": "label", "condition": "n"})
        .sort_values("n", ascending=False)
)

most_frequent_label = label_value_counts_df.label[0]
most_frequent_baseline = f1_score(y_df.values.squeeze(), np.repeat(most_frequent_label, y_df.shape[0]), average="macro")

mc_baseline = opt.mc_classification_baseline(
    y=y_df.values.squeeze(),
    labels=label_value_counts_df.label.values,
    weights=label_value_counts_df.n.values / label_value_counts_df.n.values.sum(),
    metric=lambda y, yhat: f1_score(y, yhat, average="macro"),
    n=1001
)

print(f"Most frequent baseline: {most_frequent_baseline}")
print(f"Monte Carlo baseline: {mc_baseline.mean()}")
# Out:
# Most frequent baseline: 0.487758945386064
# Monte Carlo baseline: 0.4998257180356517

# %%
model = GradientBoostingClassifier()
# model = GaussianNB()
cv_res = cross_val_score(model, x_df.values, y_df.values.squeeze(), scoring="f1_macro")

# %%
cv_res
# Out:
# array([1.        , 1.        , 0.82857143, 0.89514563, 1.        ])

# %% [markdown]
# ## SMBO

# %%
def objective(h_params, X, y, loss_default, scoring_default, r, verbose=True):
    if verbose:
        print(h_params)
    model = GradientBoostingClassifier(
        loss=loss_default,
        learning_rate=h_params[0],
        n_estimators=h_params[1],
        max_depth=h_params[2],
        max_features=h_params[3],
        min_samples_split=h_params[4],
        min_samples_leaf=h_params[5],
        random_state=r
    )
    return -np.mean(cross_val_score(
        model,
        X,
        y,
        cv=KFold(n_splits=5),
        n_jobs=-1,
        scoring=scoring_default
    ))

# %%
space = [
    Real(1e-3, 1e-1, name="learning_rate"),
    Integer(int(1e2), int(1e3), name="n_estimators"),
    Integer(2, 5, name="max_depth"),
    Categorical(["auto", "sqrt", "log2"], name="max_features"),
    Integer(int(2), int(6), name="min_samples_split"),
    Integer(int(1), int(3), name="min_samples_leaf")
]
n_initial = 10 * len(space)
n_calls = 50 * len(space)

# %%
loss_default = "deviance"
scoring_default = "f1_macro"
callback_file = f"{unified_dsets[dset_idx]}_opt_gbc_cancer_y_n_h_params_{scoring_default}.tsv"

try:
    os.remove(callback_file)
except OSError:
    pass

res = gp_minimize(
    lambda h_ps: objective(h_ps, x_df, y_df, loss_default, scoring_default, rand),
    space,
    verbose=True,
    random_state=rand,
    n_initial_points=n_initial,
    n_calls=n_calls,
    n_jobs=-1,
    callback=lambda x: opt.save_callback(x, callback_file, n = 5, sep="\t")
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.04393641609527331, 488, 3, 'log2', 3, 2]
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.4356
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 2 started. Evaluating function at random point.
# [0.08944552714859637, 950, 4, 'log2', 2, 2]
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.6716
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 3 started. Evaluating function at random point.
# [0.04206779498340956, 880, 3, 'log2', 6, 2]
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.5022
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 4 started. Evaluating function at random point.
# [0.06167655805053381, 209, 4, 'log2', 4, 2]
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.7266
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 5 started. Evaluating function at random point.
# [0.03110795811369123, 475, 4, 'sqrt', 4, 2]
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 1.2943
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 6 started. Evaluating function at random point.
# [0.05900771870365909, 662, 4, 'sqrt', 2, 3]
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 1.7155
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 7 started. Evaluating function at random point.
# [0.025122971079150534, 275, 4, 'auto', 6, 2]
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 9.3239
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 8 started. Evaluating function at random point.
# [0.07261821946080553, 115, 4, 'log2', 3, 1]
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.2896
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 9 started. Evaluating function at random point.
# [0.0698574233483202, 387, 4, 'log2', 4, 3]
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.6005
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 10 started. Evaluating function at random point.
# [0.08432532969435894, 422, 2, 'log2', 4, 2]
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.4391
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 11 started. Evaluating function at random point.
# [0.09954048972136775, 420, 4, 'log2', 5, 1]
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.6112
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 12 started. Evaluating function at random point.
# [0.04048875297988951, 317, 3, 'log2', 5, 1]
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.4556
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 13 started. Evaluating function at random point.
# [0.013958600115743996, 390, 4, 'sqrt', 4, 3]
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 1.1080
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 14 started. Evaluating function at random point.
# [0.039098943316300365, 385, 3, 'auto', 5, 2]
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 11.3520
# Function value obtained: -0.9054
# Current minimum: -0.9879
# Iteration No: 15 started. Evaluating function at random point.
# [0.055684637454113256, 621, 4, 'auto', 6, 3]
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 16.2985
# Function value obtained: -0.9573
# Current minimum: -0.9879
# Iteration No: 16 started. Evaluating function at random point.
# [0.02155595025843613, 363, 4, 'sqrt', 6, 2]
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 1.0400
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 17 started. Evaluating function at random point.
# [0.0568715452495534, 826, 3, 'log2', 3, 2]
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.8947
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 18 started. Evaluating function at random point.
# [0.08672058137202322, 985, 2, 'log2', 3, 2]
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.8933
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 19 started. Evaluating function at random point.
# [0.05522859369025656, 184, 3, 'sqrt', 4, 2]
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.5042
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 20 started. Evaluating function at random point.
# [0.07559907308901337, 768, 2, 'log2', 5, 1]
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.6995
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 21 started. Evaluating function at random point.
# [0.0783187958619958, 358, 3, 'log2', 2, 2]
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 0.4806
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 22 started. Evaluating function at random point.
# [0.08889782247494607, 727, 3, 'log2', 5, 2]
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 0.8398
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 23 started. Evaluating function at random point.
# [0.009405512155989944, 624, 4, 'log2', 6, 3]
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 0.8736
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 24 started. Evaluating function at random point.
# [0.05783231868984649, 776, 2, 'sqrt', 5, 3]
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 1.2010
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 25 started. Evaluating function at random point.
# [0.013734488553428625, 174, 2, 'log2', 4, 2]
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 0.2653
# Function value obtained: -0.8721
# Current minimum: -0.9879
# Iteration No: 26 started. Evaluating function at random point.
# [0.013102111413618004, 281, 4, 'log2', 5, 1]
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.4967
# Function value obtained: -0.8721
# Current minimum: -0.9879
# Iteration No: 27 started. Evaluating function at random point.
# [0.05560767987225816, 939, 4, 'auto', 5, 2]
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 21.6512
# Function value obtained: -0.8904
# Current minimum: -0.9879
# Iteration No: 28 started. Evaluating function at random point.
# [0.06717001077868653, 126, 4, 'auto', 5, 2]
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 4.3807
# Function value obtained: -0.9286
# Current minimum: -0.9879
# Iteration No: 29 started. Evaluating function at random point.
# [0.013053681191832318, 588, 2, 'log2', 6, 3]
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 0.5728
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 30 started. Evaluating function at random point.
# [0.057803637252223636, 192, 4, 'log2', 2, 3]
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 0.3701
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 31 started. Evaluating function at random point.
# [0.05235294249816003, 483, 4, 'log2', 4, 1]
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.7192
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 32 started. Evaluating function at random point.
# [0.032810571051136446, 861, 3, 'log2', 6, 1]
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 0.9145
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 33 started. Evaluating function at random point.
# [0.09176640096094409, 927, 2, 'log2', 4, 2]
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 0.8206
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 34 started. Evaluating function at random point.
# [0.005686614186535963, 318, 2, 'auto', 5, 3]
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 7.5553
# Function value obtained: -0.9577
# Current minimum: -0.9879
# Iteration No: 35 started. Evaluating function at random point.
# [0.005279066315885034, 372, 5, 'log2', 5, 1]
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 0.6548
# Function value obtained: -0.8368
# Current minimum: -0.9879
# Iteration No: 36 started. Evaluating function at random point.
# [0.04900603490081338, 989, 3, 'auto', 4, 3]
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 21.7058
# Function value obtained: -0.8904
# Current minimum: -0.9879
# Iteration No: 37 started. Evaluating function at random point.
# [0.03484123074293664, 819, 4, 'auto', 4, 2]
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 23.0894
# Function value obtained: -0.9439
# Current minimum: -0.9879
# Iteration No: 38 started. Evaluating function at random point.
# [0.04164145875597887, 272, 5, 'log2', 5, 1]
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 0.5631
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 39 started. Evaluating function at random point.
# [0.027423675664322345, 552, 2, 'sqrt', 3, 2]
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 0.9896
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 40 started. Evaluating function at random point.
# [0.022187179575926287, 195, 3, 'log2', 5, 2]
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 0.3466
# Function value obtained: -0.9730
# Current minimum: -0.9879
# Iteration No: 41 started. Evaluating function at random point.
# [0.03686539933668106, 105, 3, 'log2', 3, 2]
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 0.2701
# Function value obtained: -0.8721
# Current minimum: -0.9879
# Iteration No: 42 started. Evaluating function at random point.
# [0.030022094394090766, 669, 2, 'sqrt', 2, 1]
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 1.1346
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 43 started. Evaluating function at random point.
# [0.07793908369548964, 141, 4, 'sqrt', 5, 2]
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 0.5172
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 44 started. Evaluating function at random point.
# [0.09589246455914505, 487, 5, 'log2', 6, 1]
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 0.7908
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 45 started. Evaluating function at random point.
# [0.0940628724778991, 849, 5, 'auto', 4, 1]
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 18.5581
# Function value obtained: -0.8904
# Current minimum: -0.9879
# Iteration No: 46 started. Evaluating function at random point.
# [0.07239725223901008, 107, 2, 'auto', 6, 2]
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 2.6130
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 47 started. Evaluating function at random point.
# [0.054456033586043305, 611, 3, 'log2', 5, 2]
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 0.7250
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 48 started. Evaluating function at random point.
# [0.04244405903902258, 508, 5, 'log2', 6, 2]
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 0.8704
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 49 started. Evaluating function at random point.
# [0.05055558066406103, 103, 3, 'sqrt', 3, 1]
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 0.3493
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 50 started. Evaluating function at random point.
# [0.041271110453913, 435, 5, 'auto', 6, 2]
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 16.5318
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 51 started. Evaluating function at random point.
# [0.09051837341235758, 647, 4, 'log2', 3, 2]
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 0.8413
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 52 started. Evaluating function at random point.
# [0.07572491107570557, 432, 3, 'sqrt', 6, 2]
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 1.0285
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 53 started. Evaluating function at random point.
# [0.0638291689555467, 346, 3, 'log2', 3, 3]
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 0.4673
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 54 started. Evaluating function at random point.
# [0.08240807765764883, 739, 5, 'log2', 3, 1]
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 1.0051
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 55 started. Evaluating function at random point.
# [0.03080428246191879, 231, 2, 'log2', 3, 2]
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 0.3008
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 56 started. Evaluating function at random point.
# [0.019942236351335112, 709, 3, 'log2', 5, 2]
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 0.8039
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 57 started. Evaluating function at random point.
# [0.03414880487383491, 589, 4, 'sqrt', 4, 1]
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 1.5544
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 58 started. Evaluating function at random point.
# [0.07492306544687317, 800, 3, 'sqrt', 4, 3]
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 1.5775
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 59 started. Evaluating function at random point.
# [0.02451034377883833, 399, 5, 'log2', 5, 2]
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 0.7248
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 60 started. Evaluating function at random point.
# [0.021226107666994846, 524, 4, 'log2', 2, 1]
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 3.1616
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 61 started. Searching for the next optimal point.
# [0.02881642751166136, 285, 2, 'log2', 4, 2]
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 2.5877
# Function value obtained: -0.9730
# Current minimum: -0.9879
# Iteration No: 62 started. Searching for the next optimal point.
# [0.033176421212254996, 416, 5, 'log2', 6, 2]
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 2.6093
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 63 started. Searching for the next optimal point.
# [0.012945077395413621, 708, 3, 'log2', 5, 3]
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 2.3878
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 64 started. Searching for the next optimal point.
# [0.092876556171875, 100, 3, 'auto', 5, 2]
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 4.4397
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 65 started. Searching for the next optimal point.
# [0.044363283932765334, 326, 5, 'auto', 3, 1]
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 15.3716
# Function value obtained: -0.9207
# Current minimum: -0.9879
# Iteration No: 66 started. Searching for the next optimal point.
# [0.026005202054536655, 593, 3, 'log2', 6, 3]
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 2.6147
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 67 started. Searching for the next optimal point.
# [0.04931521302554132, 364, 5, 'log2', 4, 2]
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 1.8685
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 68 started. Searching for the next optimal point.
# [0.06712328112681418, 286, 2, 'sqrt', 2, 1]
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 3.5231
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 69 started. Searching for the next optimal point.
# [0.1, 606, 3, 'sqrt', 3, 3]
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 3.0953
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 70 started. Searching for the next optimal point.
# [0.1, 1000, 3, 'sqrt', 5, 2]
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 4.1232
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 71 started. Searching for the next optimal point.
# [0.0920135668791742, 787, 4, 'sqrt', 3, 2]
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 3.7300
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 72 started. Searching for the next optimal point.
# [0.08354738729284804, 612, 5, 'sqrt', 2, 1]
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 3.2434
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 73 started. Searching for the next optimal point.
# [0.1, 259, 3, 'sqrt', 2, 2]
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 2.3428
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 74 started. Searching for the next optimal point.
# [0.08942106486708563, 370, 2, 'sqrt', 4, 3]
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 3.3590
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 75 started. Searching for the next optimal point.
# [0.04937133004127391, 411, 2, 'sqrt', 4, 2]
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 2.5484
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 76 started. Searching for the next optimal point.
# [0.03462710577264422, 388, 4, 'log2', 2, 3]
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 2.4373
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 77 started. Searching for the next optimal point.
# [0.03646881366667714, 222, 4, 'sqrt', 2, 2]
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 2.7801
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 78 started. Searching for the next optimal point.
# [0.08963717196257855, 190, 5, 'log2', 3, 2]
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 2.9961
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 79 started. Searching for the next optimal point.
# [0.06834382972493226, 1000, 4, 'log2', 6, 2]
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 2.3345
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 80 started. Searching for the next optimal point.
# [0.001, 767, 4, 'sqrt', 5, 3]
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 4.5891
# Function value obtained: -0.7970
# Current minimum: -0.9879
# Iteration No: 81 started. Searching for the next optimal point.
# [0.015808369606525215, 204, 4, 'sqrt', 3, 2]
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 3.3117
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 82 started. Searching for the next optimal point.
# [0.001, 1000, 3, 'log2', 6, 3]
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 3.1885
# Function value obtained: -0.8180
# Current minimum: -0.9879
# Iteration No: 83 started. Searching for the next optimal point.
# [0.01788451739073414, 644, 5, 'log2', 6, 3]
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 3.5051
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 84 started. Searching for the next optimal point.
# [0.08865071693668128, 275, 4, 'auto', 5, 3]
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 10.3236
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 85 started. Searching for the next optimal point.
# [0.03221824453095568, 747, 5, 'log2', 5, 3]
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 3.0782
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 86 started. Searching for the next optimal point.
# [0.04749831174487694, 1000, 3, 'sqrt', 3, 1]
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 3.5836
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 87 started. Searching for the next optimal point.
# [0.014189237847101237, 613, 5, 'auto', 3, 2]
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 27.5064
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 88 started. Searching for the next optimal point.
# [0.08160777498950116, 911, 3, 'log2', 5, 2]
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 3.4473
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 89 started. Searching for the next optimal point.
# [0.08211937406200834, 911, 3, 'log2', 5, 2]
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 4.4289
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 90 started. Searching for the next optimal point.
# [0.06750429265766358, 667, 3, 'sqrt', 5, 3]
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 4.6241
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 91 started. Searching for the next optimal point.
# [0.060754969832808224, 413, 3, 'sqrt', 5, 1]
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 4.7171
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 92 started. Searching for the next optimal point.
# [0.07456002151218966, 1000, 4, 'sqrt', 2, 1]
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 4.5862
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 93 started. Searching for the next optimal point.
# [0.08243262053608459, 910, 3, 'log2', 5, 1]
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 2.9886
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 94 started. Searching for the next optimal point.
# [0.08291950135911319, 908, 3, 'log2', 4, 3]
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 3.9736
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 95 started. Searching for the next optimal point.
# [0.042805824566330426, 751, 2, 'sqrt', 3, 2]
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 4.0423
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 96 started. Searching for the next optimal point.
# [0.1, 100, 2, 'log2', 3, 3]
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 2.7402
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 97 started. Searching for the next optimal point.
# [0.08326277764831025, 700, 5, 'sqrt', 5, 3]
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 4.1256
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 98 started. Searching for the next optimal point.
# [0.029198558958216044, 253, 5, 'log2', 2, 3]
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 2.9899
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 99 started. Searching for the next optimal point.
# [0.1, 100, 2, 'sqrt', 6, 2]
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 3.6486
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 100 started. Searching for the next optimal point.
# [0.03208305554845907, 381, 4, 'log2', 6, 2]
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 3.2599
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 101 started. Searching for the next optimal point.
# [0.017517322926144167, 531, 4, 'sqrt', 3, 2]
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 5.0181
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 102 started. Searching for the next optimal point.
# [0.09351166603536541, 357, 3, 'auto', 5, 3]
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 10.3283
# Function value obtained: -0.9439
# Current minimum: -0.9879
# Iteration No: 103 started. Searching for the next optimal point.
# [0.09770717283986248, 542, 4, 'log2', 4, 2]
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 3.2251
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 104 started. Searching for the next optimal point.
# [0.08706008686420098, 866, 3, 'log2', 5, 2]
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 4.5436
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 105 started. Searching for the next optimal point.
# [0.08169815769157279, 101, 2, 'auto', 6, 3]
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 5.7314
# Function value obtained: -0.9439
# Current minimum: -0.9879
# Iteration No: 106 started. Searching for the next optimal point.
# [0.08559346866982914, 880, 4, 'log2', 5, 2]
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 4.3784
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 107 started. Searching for the next optimal point.
# [0.040510731925100164, 545, 5, 'auto', 6, 2]
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 20.4887
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 108 started. Searching for the next optimal point.
# [0.0590005293493614, 1000, 5, 'sqrt', 2, 3]
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 5.4959
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 109 started. Searching for the next optimal point.
# [0.0709188051047477, 115, 4, 'sqrt', 4, 2]
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 4.1202
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 110 started. Searching for the next optimal point.
# [0.034126762857821874, 580, 5, 'sqrt', 3, 2]
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 4.2513
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 111 started. Searching for the next optimal point.
# [0.08590566004911332, 880, 3, 'log2', 5, 1]
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 3.2916
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 112 started. Searching for the next optimal point.
# [0.06707371070365128, 859, 5, 'log2', 5, 2]
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 5.2835
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 113 started. Searching for the next optimal point.
# [0.014367409539475077, 100, 5, 'auto', 4, 2]
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 9.2342
# Function value obtained: -0.9577
# Current minimum: -0.9879
# Iteration No: 114 started. Searching for the next optimal point.
# [0.051917998891338024, 1000, 5, 'log2', 4, 1]
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 5.0680
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 115 started. Searching for the next optimal point.
# [0.053001354056898355, 457, 5, 'auto', 3, 2]
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 19.2226
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 116 started. Searching for the next optimal point.
# [0.1, 100, 5, 'auto', 2, 1]
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 8.3060
# Function value obtained: -0.9054
# Current minimum: -0.9879
# Iteration No: 117 started. Searching for the next optimal point.
# [0.037762937808026927, 1000, 5, 'sqrt', 3, 1]
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 8.0053
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 118 started. Searching for the next optimal point.
# [0.054302722546898045, 954, 5, 'log2', 5, 1]
# Iteration No: 118 ended. Search finished for the next optimal point.
# Time taken: 4.7437
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 119 started. Searching for the next optimal point.
# [0.04185735125371634, 370, 5, 'log2', 6, 1]
# Iteration No: 119 ended. Search finished for the next optimal point.
# Time taken: 4.4383
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 120 started. Searching for the next optimal point.
# [0.08923952731197828, 876, 2, 'log2', 4, 2]
# Iteration No: 120 ended. Search finished for the next optimal point.
# Time taken: 4.9341
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 121 started. Searching for the next optimal point.
# [0.08725941261366144, 1000, 5, 'sqrt', 3, 3]
# Iteration No: 121 ended. Search finished for the next optimal point.
# Time taken: 5.9774
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 122 started. Searching for the next optimal point.
# [0.001, 1000, 5, 'auto', 5, 2]
# Iteration No: 122 ended. Search finished for the next optimal point.
# Time taken: 37.5339
# Function value obtained: -0.9577
# Current minimum: -0.9879
# Iteration No: 123 started. Searching for the next optimal point.
# [0.08953547303478826, 866, 4, 'log2', 5, 2]
# Iteration No: 123 ended. Search finished for the next optimal point.
# Time taken: 5.1442
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 124 started. Searching for the next optimal point.
# [0.001, 100, 2, 'sqrt', 4, 2]
# Iteration No: 124 ended. Search finished for the next optimal point.
# Time taken: 3.3534
# Function value obtained: -0.5876
# Current minimum: -0.9879
# Iteration No: 125 started. Searching for the next optimal point.
# [0.022583981451421212, 113, 5, 'sqrt', 2, 3]
# Iteration No: 125 ended. Search finished for the next optimal point.
# Time taken: 4.3055
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 126 started. Searching for the next optimal point.
# [0.04581408927517119, 503, 5, 'auto', 6, 3]
# Iteration No: 126 ended. Search finished for the next optimal point.
# Time taken: 20.8565
# Function value obtained: -0.9439
# Current minimum: -0.9879
# Iteration No: 127 started. Searching for the next optimal point.
# [0.0076686150016078685, 717, 2, 'auto', 5, 2]
# Iteration No: 127 ended. Search finished for the next optimal point.
# Time taken: 21.0599
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 128 started. Searching for the next optimal point.
# [0.03613272786717859, 453, 5, 'log2', 2, 3]
# Iteration No: 128 ended. Search finished for the next optimal point.
# Time taken: 5.2250
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 129 started. Searching for the next optimal point.
# [0.042903783083160354, 278, 2, 'sqrt', 2, 3]
# Iteration No: 129 ended. Search finished for the next optimal point.
# Time taken: 4.9158
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 130 started. Searching for the next optimal point.
# [0.026926328124456583, 1000, 5, 'log2', 4, 2]
# Iteration No: 130 ended. Search finished for the next optimal point.
# Time taken: 5.6283
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 131 started. Searching for the next optimal point.
# [0.07499636203310016, 1000, 5, 'auto', 4, 1]
# Iteration No: 131 ended. Search finished for the next optimal point.
# Time taken: 27.0593
# Function value obtained: -0.8904
# Current minimum: -0.9879
# Iteration No: 132 started. Searching for the next optimal point.
# [0.032098958414063336, 388, 5, 'log2', 2, 2]
# Iteration No: 132 ended. Search finished for the next optimal point.
# Time taken: 4.1048
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 133 started. Searching for the next optimal point.
# [0.03220559291345922, 312, 5, 'log2', 6, 3]
# Iteration No: 133 ended. Search finished for the next optimal point.
# Time taken: 4.3198
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 134 started. Searching for the next optimal point.
# [0.03506846312269872, 435, 2, 'log2', 2, 3]
# Iteration No: 134 ended. Search finished for the next optimal point.
# Time taken: 4.0816
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 135 started. Searching for the next optimal point.
# [0.03500079477519561, 408, 4, 'log2', 6, 3]
# Iteration No: 135 ended. Search finished for the next optimal point.
# Time taken: 5.1328
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 136 started. Searching for the next optimal point.
# [0.03499101912888784, 411, 2, 'log2', 2, 3]
# Iteration No: 136 ended. Search finished for the next optimal point.
# Time taken: 6.0849
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 137 started. Searching for the next optimal point.
# [0.03481034120055017, 413, 2, 'log2', 2, 3]
# Iteration No: 137 ended. Search finished for the next optimal point.
# Time taken: 6.3356
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 138 started. Searching for the next optimal point.
# [0.02947864764145125, 159, 5, 'log2', 2, 3]
# Iteration No: 138 ended. Search finished for the next optimal point.
# Time taken: 4.9585
# Function value obtained: -0.9730
# Current minimum: -0.9879
# Iteration No: 139 started. Searching for the next optimal point.
# [0.02311540604808551, 802, 5, 'auto', 4, 3]
# Iteration No: 139 ended. Search finished for the next optimal point.
# Time taken: 35.1687
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 140 started. Searching for the next optimal point.
# [0.023936942908644964, 1000, 5, 'sqrt', 3, 3]
# Iteration No: 140 ended. Search finished for the next optimal point.
# Time taken: 7.0804
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 141 started. Searching for the next optimal point.
# [0.03521935053313696, 408, 2, 'log2', 2, 2]
# Iteration No: 141 ended. Search finished for the next optimal point.
# Time taken: 4.8300
# Function value obtained: -0.9730
# Current minimum: -0.9879
# Iteration No: 142 started. Searching for the next optimal point.
# [0.03452020701460138, 538, 5, 'log2', 3, 3]
# Iteration No: 142 ended. Search finished for the next optimal point.
# Time taken: 3.6106
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 143 started. Searching for the next optimal point.
# [0.012514936330581747, 1000, 2, 'sqrt', 5, 3]
# Iteration No: 143 ended. Search finished for the next optimal point.
# Time taken: 5.7857
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 144 started. Searching for the next optimal point.
# [0.05302684777797611, 1000, 4, 'sqrt', 6, 1]
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 5.7657
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 145 started. Searching for the next optimal point.
# [0.017491470300199333, 269, 2, 'sqrt', 3, 3]
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 5.3448
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 146 started. Searching for the next optimal point.
# [0.032580938652897615, 413, 5, 'log2', 4, 3]
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 5.0859
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 147 started. Searching for the next optimal point.
# [0.013639870762589431, 716, 4, 'sqrt', 6, 3]
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 5.7100
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 148 started. Searching for the next optimal point.
# [0.09575591970383425, 100, 3, 'log2', 5, 3]
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 5.8470
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 149 started. Searching for the next optimal point.
# [0.06601344213688926, 1000, 2, 'sqrt', 3, 1]
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 4.9878
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 150 started. Searching for the next optimal point.
# [0.03333458773859058, 447, 5, 'log2', 6, 3]
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 4.7840
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 151 started. Searching for the next optimal point.
# [0.033119887531203526, 430, 5, 'log2', 5, 3]
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 5.9725
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 152 started. Searching for the next optimal point.
# [0.03322923563000586, 424, 5, 'log2', 3, 3]
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 5.5664
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 153 started. Searching for the next optimal point.
# [0.022918356306770464, 492, 5, 'log2', 2, 3]
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 6.3641
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 154 started. Searching for the next optimal point.
# [0.0338650301726797, 442, 5, 'log2', 5, 3]
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 4.8268
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 155 started. Searching for the next optimal point.
# [0.1, 1000, 5, 'log2', 5, 1]
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 5.8745
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 156 started. Searching for the next optimal point.
# [0.028691140980542266, 638, 4, 'log2', 4, 3]
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 5.4739
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 157 started. Searching for the next optimal point.
# [0.033167541684041554, 415, 5, 'log2', 3, 3]
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 4.2444
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 158 started. Searching for the next optimal point.
# [0.03087841757319088, 1000, 3, 'sqrt', 3, 3]
# Iteration No: 158 ended. Search finished for the next optimal point.
# Time taken: 8.6373
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 159 started. Searching for the next optimal point.
# [0.03358242282455237, 427, 5, 'log2', 5, 3]
# Iteration No: 159 ended. Search finished for the next optimal point.
# Time taken: 6.5157
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 160 started. Searching for the next optimal point.
# [0.040561493763890066, 429, 2, 'log2', 2, 3]
# Iteration No: 160 ended. Search finished for the next optimal point.
# Time taken: 5.4572
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 161 started. Searching for the next optimal point.
# [0.033522112694627, 419, 5, 'log2', 5, 3]
# Iteration No: 161 ended. Search finished for the next optimal point.
# Time taken: 5.1329
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 162 started. Searching for the next optimal point.
# [0.03351483991252778, 416, 5, 'log2', 6, 3]
# Iteration No: 162 ended. Search finished for the next optimal point.
# Time taken: 6.1921
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 163 started. Searching for the next optimal point.
# [0.013461527716741577, 1000, 4, 'auto', 2, 2]
# Iteration No: 163 ended. Search finished for the next optimal point.
# Time taken: 41.9527
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 164 started. Searching for the next optimal point.
# [0.04208197114902003, 613, 5, 'auto', 5, 3]
# Iteration No: 164 ended. Search finished for the next optimal point.
# Time taken: 24.8353
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 165 started. Searching for the next optimal point.
# [0.043165971863330196, 566, 5, 'auto', 6, 2]
# Iteration No: 165 ended. Search finished for the next optimal point.
# Time taken: 24.9044
# Function value obtained: -0.9726
# Current minimum: -0.9879
# Iteration No: 166 started. Searching for the next optimal point.
# [0.04622872816368197, 729, 5, 'log2', 2, 3]
# Iteration No: 166 ended. Search finished for the next optimal point.
# Time taken: 7.1353
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 167 started. Searching for the next optimal point.
# [0.05496631932364303, 210, 3, 'auto', 4, 3]
# Iteration No: 167 ended. Search finished for the next optimal point.
# Time taken: 13.3166
# Function value obtained: -0.9439
# Current minimum: -0.9879
# Iteration No: 168 started. Searching for the next optimal point.
# [0.043883362219066656, 275, 2, 'log2', 2, 1]
# Iteration No: 168 ended. Search finished for the next optimal point.
# Time taken: 6.4407
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 169 started. Searching for the next optimal point.
# [0.016162823467740426, 366, 5, 'sqrt', 6, 3]
# Iteration No: 169 ended. Search finished for the next optimal point.
# Time taken: 6.3155
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 170 started. Searching for the next optimal point.
# [0.03317695899104499, 388, 5, 'log2', 5, 3]
# Iteration No: 170 ended. Search finished for the next optimal point.
# Time taken: 7.9763
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 171 started. Searching for the next optimal point.
# [0.03311413814176366, 384, 5, 'log2', 5, 3]
# Iteration No: 171 ended. Search finished for the next optimal point.
# Time taken: 7.4164
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 172 started. Searching for the next optimal point.
# [0.03302558939583051, 381, 5, 'log2', 5, 3]
# Iteration No: 172 ended. Search finished for the next optimal point.
# Time taken: 7.5428
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 173 started. Searching for the next optimal point.
# [0.06226814542402896, 100, 3, 'sqrt', 4, 3]
# Iteration No: 173 ended. Search finished for the next optimal point.
# Time taken: 6.5665
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 174 started. Searching for the next optimal point.
# [0.034931525959808786, 433, 5, 'log2', 3, 3]
# Iteration No: 174 ended. Search finished for the next optimal point.
# Time taken: 6.5222
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 175 started. Searching for the next optimal point.
# [0.016095680854381497, 1000, 3, 'sqrt', 3, 2]
# Iteration No: 175 ended. Search finished for the next optimal point.
# Time taken: 9.0358
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 176 started. Searching for the next optimal point.
# [0.03496019449298575, 431, 5, 'log2', 6, 3]
# Iteration No: 176 ended. Search finished for the next optimal point.
# Time taken: 8.3114
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 177 started. Searching for the next optimal point.
# [0.08584910304580283, 100, 5, 'sqrt', 2, 1]
# Iteration No: 177 ended. Search finished for the next optimal point.
# Time taken: 6.5584
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 178 started. Searching for the next optimal point.
# [0.09703703213163367, 740, 2, 'sqrt', 3, 1]
# Iteration No: 178 ended. Search finished for the next optimal point.
# Time taken: 7.7733
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 179 started. Searching for the next optimal point.
# [0.032975753152463844, 377, 5, 'log2', 5, 3]
# Iteration No: 179 ended. Search finished for the next optimal point.
# Time taken: 5.8770
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 180 started. Searching for the next optimal point.
# [0.0960384544862808, 522, 4, 'sqrt', 6, 3]
# Iteration No: 180 ended. Search finished for the next optimal point.
# Time taken: 8.4639
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 181 started. Searching for the next optimal point.
# [0.028398563285220682, 100, 2, 'sqrt', 4, 1]
# Iteration No: 181 ended. Search finished for the next optimal point.
# Time taken: 5.9491
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 182 started. Searching for the next optimal point.
# [0.03483948186861063, 426, 5, 'log2', 4, 3]
# Iteration No: 182 ended. Search finished for the next optimal point.
# Time taken: 7.8549
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 183 started. Searching for the next optimal point.
# [0.03485449601905933, 426, 4, 'log2', 6, 3]
# Iteration No: 183 ended. Search finished for the next optimal point.
# Time taken: 8.3609
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 184 started. Searching for the next optimal point.
# [0.03480279791615205, 424, 5, 'log2', 2, 3]
# Iteration No: 184 ended. Search finished for the next optimal point.
# Time taken: 8.6142
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 185 started. Searching for the next optimal point.
# [0.0348269139358228, 425, 4, 'log2', 4, 3]
# Iteration No: 185 ended. Search finished for the next optimal point.
# Time taken: 8.6787
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 186 started. Searching for the next optimal point.
# [0.03482994837690478, 425, 4, 'log2', 6, 3]
# Iteration No: 186 ended. Search finished for the next optimal point.
# Time taken: 7.0907
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 187 started. Searching for the next optimal point.
# [0.034833717346832486, 425, 5, 'log2', 5, 3]
# Iteration No: 187 ended. Search finished for the next optimal point.
# Time taken: 8.6956
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 188 started. Searching for the next optimal point.
# [0.034793639614649444, 423, 5, 'log2', 2, 3]
# Iteration No: 188 ended. Search finished for the next optimal point.
# Time taken: 7.3654
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 189 started. Searching for the next optimal point.
# [0.03480479167009213, 423, 4, 'log2', 3, 3]
# Iteration No: 189 ended. Search finished for the next optimal point.
# Time taken: 7.1163
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 190 started. Searching for the next optimal point.
# [0.034804177417275574, 423, 4, 'log2', 3, 3]
# Iteration No: 190 ended. Search finished for the next optimal point.
# Time taken: 7.5004
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 191 started. Searching for the next optimal point.
# [0.04076112157022872, 375, 3, 'sqrt', 4, 1]
# Iteration No: 191 ended. Search finished for the next optimal point.
# Time taken: 8.2904
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 192 started. Searching for the next optimal point.
# [0.03465341656932119, 416, 5, 'log2', 4, 3]
# Iteration No: 192 ended. Search finished for the next optimal point.
# Time taken: 7.7564
# Function value obtained: -0.9879
# Current minimum: -0.9879
# ...
# [0.034663031163483744, 413, 4, 'log2', 2, 3]
# Iteration No: 226 ended. Search finished for the next optimal point.
# Time taken: 8.7185
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 227 started. Searching for the next optimal point.
# [0.034670803302547716, 413, 4, 'log2', 2, 3]
# Iteration No: 227 ended. Search finished for the next optimal point.
# Time taken: 8.2121
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 228 started. Searching for the next optimal point.
# [0.03467070447409242, 413, 4, 'log2', 2, 3]
# Iteration No: 228 ended. Search finished for the next optimal point.
# Time taken: 8.6693
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 229 started. Searching for the next optimal point.
# [0.034666884155989244, 412, 4, 'log2', 2, 3]
# Iteration No: 229 ended. Search finished for the next optimal point.
# Time taken: 8.2428
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 230 started. Searching for the next optimal point.
# [0.03467799950176744, 415, 4, 'log2', 2, 3]
# Iteration No: 230 ended. Search finished for the next optimal point.
# Time taken: 7.9209
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 231 started. Searching for the next optimal point.
# [0.03467035890127327, 413, 4, 'log2', 2, 3]
# Iteration No: 231 ended. Search finished for the next optimal point.
# Time taken: 7.8697
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 232 started. Searching for the next optimal point.
# [0.03468081990643364, 413, 4, 'log2', 4, 3]
# Iteration No: 232 ended. Search finished for the next optimal point.
# Time taken: 8.1857
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 233 started. Searching for the next optimal point.
# [0.034765990491086196, 409, 3, 'log2', 4, 3]
# Iteration No: 233 ended. Search finished for the next optimal point.
# Time taken: 7.2685
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 234 started. Searching for the next optimal point.
# [0.034669499189917574, 413, 4, 'log2', 2, 3]
# Iteration No: 234 ended. Search finished for the next optimal point.
# Time taken: 8.8878
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 235 started. Searching for the next optimal point.
# [0.03466777145894569, 413, 5, 'log2', 2, 3]
# Iteration No: 235 ended. Search finished for the next optimal point.
# Time taken: 7.7062
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 236 started. Searching for the next optimal point.
# [0.034658105629453845, 412, 4, 'log2', 2, 3]
# Iteration No: 236 ended. Search finished for the next optimal point.
# Time taken: 7.1175
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 237 started. Searching for the next optimal point.
# [0.03466796810613519, 413, 5, 'log2', 2, 3]
# Iteration No: 237 ended. Search finished for the next optimal point.
# Time taken: 7.9889
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 238 started. Searching for the next optimal point.
# [0.034668004405177665, 413, 4, 'log2', 2, 3]
# Iteration No: 238 ended. Search finished for the next optimal point.
# Time taken: 7.4448
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 239 started. Searching for the next optimal point.
# [0.03465152496706336, 413, 5, 'log2', 2, 3]
# Iteration No: 239 ended. Search finished for the next optimal point.
# Time taken: 8.2072
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 240 started. Searching for the next optimal point.
# [0.03475254220924822, 409, 3, 'log2', 3, 3]
# Iteration No: 240 ended. Search finished for the next optimal point.
# Time taken: 8.4043
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 241 started. Searching for the next optimal point.
# [0.03466597536674516, 413, 5, 'log2', 2, 3]
# Iteration No: 241 ended. Search finished for the next optimal point.
# Time taken: 8.0547
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 242 started. Searching for the next optimal point.
# [0.034666572867501716, 413, 4, 'log2', 2, 3]
# Iteration No: 242 ended. Search finished for the next optimal point.
# Time taken: 9.3155
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 243 started. Searching for the next optimal point.
# [0.03466651262201436, 413, 3, 'log2', 2, 3]
# Iteration No: 243 ended. Search finished for the next optimal point.
# Time taken: 8.5153
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 244 started. Searching for the next optimal point.
# [0.03467641629608847, 413, 4, 'log2', 4, 3]
# Iteration No: 244 ended. Search finished for the next optimal point.
# Time taken: 8.2790
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 245 started. Searching for the next optimal point.
# [0.03467605811287545, 413, 4, 'log2', 4, 3]
# Iteration No: 245 ended. Search finished for the next optimal point.
# Time taken: 9.1834
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 246 started. Searching for the next optimal point.
# [0.034639251696027135, 412, 4, 'log2', 2, 3]
# Iteration No: 246 ended. Search finished for the next optimal point.
# Time taken: 9.9372
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 247 started. Searching for the next optimal point.
# [0.034669631409111445, 413, 5, 'log2', 3, 3]
# Iteration No: 247 ended. Search finished for the next optimal point.
# Time taken: 8.3136
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 248 started. Searching for the next optimal point.
# [0.034669863618748464, 413, 4, 'log2', 3, 3]
# Iteration No: 248 ended. Search finished for the next optimal point.
# Time taken: 9.7135
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 249 started. Searching for the next optimal point.
# [0.03466944145704957, 413, 5, 'log2', 2, 3]
# Iteration No: 249 ended. Search finished for the next optimal point.
# Time taken: 10.4691
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 250 started. Searching for the next optimal point.
# [0.03466939002402776, 413, 4, 'log2', 3, 3]
# Iteration No: 250 ended. Search finished for the next optimal point.
# Time taken: 8.3693
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 251 started. Searching for the next optimal point.
# [0.0346641046748288, 412, 4, 'log2', 2, 3]
# Iteration No: 251 ended. Search finished for the next optimal point.
# Time taken: 8.9652
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 252 started. Searching for the next optimal point.
# [0.034676693793505936, 412, 4, 'log2', 2, 3]
# Iteration No: 252 ended. Search finished for the next optimal point.
# Time taken: 9.1103
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 253 started. Searching for the next optimal point.
# [0.03476139313402928, 409, 3, 'log2', 5, 3]
# Iteration No: 253 ended. Search finished for the next optimal point.
# Time taken: 11.1317
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 254 started. Searching for the next optimal point.
# [0.03466043150364971, 412, 5, 'log2', 2, 3]
# Iteration No: 254 ended. Search finished for the next optimal point.
# Time taken: 8.2783
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 255 started. Searching for the next optimal point.
# [0.034662388535297385, 412, 4, 'log2', 2, 3]
# Iteration No: 255 ended. Search finished for the next optimal point.
# Time taken: 11.9287
# Function value obtained: -0.9879
# Current minimum: -0.9879
# Iteration No: 256 started. Searching for the next optimal point.
# [0.034650571178708414, 411, 4, 'log2', 2, 3]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-96e8d20625a1> in <module>
#       8     pass
#       9
# ---> 10 res = gp_minimize(
#      11     lambda h_ps: objective(h_ps, x_df, y_df, loss_default, scoring_default, rand),
#      12     space,
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     257             noise=noise)
#     258
# --> 259     return base_minimize(
#     260         func, space, base_estimator=base_estimator,
#     261         acq_func=acq_func,
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     300         next_x = optimizer.ask()
#     301         next_y = func(next_x)
# --> 302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#     304         if eval_callbacks(callbacks, result):
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/skopt/optimizer/optimizer.py in tell(self, x, y, fit)
#     491                 y[1] = log(y[1])
#     492
# --> 493         return self._tell(x, y, fit=fit)
#     494
#     495     def _tell(self, x, y, fit=True):
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/skopt/optimizer/optimizer.py in _tell(self, x, y, fit)
#     534             with warnings.catch_warnings():
#     535                 warnings.simplefilter("ignore")
# --> 536                 est.fit(self.space.transform(self.Xi), self.yi)
#     537
#     538             if hasattr(self, "next_xs_") and self.acq_func == "gp_hedge":
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/skopt/learning/gaussian_process/gpr.py in fit(self, X, y)
#     193                 noise_level=self.noise, noise_level_bounds="fixed"
#     194             )
# --> 195         super(GaussianProcessRegressor, self).fit(X, y)
#     196
#     197         self.noise_ = None
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in fit(self, X, y)
#     246                         self._rng.uniform(bounds[:, 0], bounds[:, 1])
#     247                     optima.append(
# --> 248                         self._constrained_optimization(obj_func, theta_initial,
#     249                                                        bounds))
#     250             # Select result from run with minimal (negative) log-marginal
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     499     def _constrained_optimization(self, obj_func, initial_theta, bounds):
#     500         if self.optimizer == "fmin_l_bfgs_b":
# --> 501             opt_res = scipy.optimize.minimize(
#     502                 obj_func, initial_theta, method="L-BFGS-B", jac=True,
#     503                 bounds=bounds)
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in obj_func(theta, eval_gradient)
#     222             def obj_func(theta, eval_gradient=True):
#     223                 if eval_gradient:
# --> 224                     lml, grad = self.log_marginal_likelihood(
#     225                         theta, eval_gradient=True, clone_kernel=False)
#     226                     return -lml, -grad
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in log_marginal_likelihood(self, theta, eval_gradient, clone_kernel)
#     458
#     459         if eval_gradient:
# --> 460             K, K_gradient = kernel(self.X_train_, eval_gradient=True)
#     461         else:
#     462             K = kernel(self.X_train_)
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#     752         """
#     753         if eval_gradient:
# --> 754             K1, K1_gradient = self.k1(X, Y, eval_gradient=True)
#     755             K2, K2_gradient = self.k2(X, Y, eval_gradient=True)
#     756             return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#     851         if eval_gradient:
#     852             K1, K1_gradient = self.k1(X, Y, eval_gradient=True)
# --> 853             K2, K2_gradient = self.k2(X, Y, eval_gradient=True)
#     854             return K1 * K2, np.dstack((K1_gradient * K2[:, :, np.newaxis],
#     855                                        K2_gradient * K1[:, :, np.newaxis]))
#
# ~/anaconda3/envs/TCGA-round1/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#    1629             elif self.nu == 2.5:
#    1630                 tmp = np.sqrt(5 * D.sum(-1))[..., np.newaxis]
# -> 1631                 K_gradient = 5.0 / 3.0 * D * (tmp + 1) * np.exp(-tmp)
#    1632             elif self.nu == np.inf:
#    1633                 K_gradient = D * K[..., np.newaxis]
#
# KeyboardInterrupt:
