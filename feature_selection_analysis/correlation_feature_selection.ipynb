# %%
library(tidyverse)

# Custom package
library(rutils)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
dirs <- rutils::get_dev_directories(dev_paths_file = "../dev_paths.txt")
projects <- c("TCGA-CESC", "TCGA-UCS", "TCGA-UCEC", "TCGA-OV")
unified_dsets <- c("unified_cervical_data", "unified_uterine_data", "unified_uterine_endometrial_data")
matrisome_path <- paste0(dirs$data_dir, "/matrisome/matrisome_hs_masterlist.tsv")

# %%
i <- 1

# %%
matrisome_df <- load_matrisome_df(matrisome_path)
# Out:
# Parsed with column specification:
# cols(
#   Division = col_character(),
#   Category = col_character(),
#   `Gene Symbol` = col_character(),
#   `Gene Name` = col_character(),
#   Synonyms = col_character(),
#   HGNC_IDs = col_double(),
#   `HGNC_IDs Links` = col_double(),
#   UniProt_IDs = col_character(),
#   Refseq_IDs = col_character(),
#   Orthology = col_character(),
#   Notes = col_character()
# )

# %% [markdown]
# # Load and filter survival data

# %%
event_code <- list("Alive" = 0, "Dead" = 1)
covariate_cols_no_figo <- c("age_at_diagnosis", "bmi", "race", "ethnicity")
covariate_cols <- c("figo_stage", covariate_cols_no_figo)
dep_cols <- c("vital_status", "survival_time")

# %%
survival_path <- paste0(dirs$data_dir, "/", unified_dsets[i], "/survival_data.tsv")
survival_df <- load_survival_df(survival_path, event_code)
# Out:
# Parsed with column specification:
# cols(
#   sample_name = col_character(),
#   vital_status = col_character(),
#   survival_time = col_double(),
#   figo_stage = col_character(),
#   days_to_last_follow_up = col_double(),
#   days_to_death = col_double(),
#   age_at_diagnosis = col_double(),
#   age_at_index = col_double(),
#   height = col_double(),
#   weight = col_double(),
#   bmi = col_double(),
#   race = col_character(),
#   ethnicity = col_character()
# )

# %%
survival_df
# Out:
#     sample_name                  vital_status survival_time figo_stage
# 1   TCGA-C5-A1BF-01B-11R-A13Y-07 1             570          Stage IB
# 2   TCGA-MU-A51Y-01A-11R-A26T-07 0             854          Stage IIA1
# 3   TCGA-EK-A2RM-01A-21R-A18M-07 0              50          Stage IB
# 4   TCGA-Q1-A73P-01A-11R-A32P-07 0             483          Stage IB1
# 5   TCGA-C5-A8YT-01A-11R-A37O-07 1             633          Stage IB1
# 6   TCGA-C5-A2LZ-01A-11R-A213-07 1            3046          Stage IIIB
# 7   TCGA-UC-A7PI-01A-11R-A42S-07 0            2114          Stage IB1
# 8   TCGA-VS-A9V1-01A-11R-A42T-07 1             157          Stage IVB
# 9   TCGA-FU-A5XV-01A-11R-A28H-07 0             321          Stage IIIB
# 10  TCGA-C5-A1BE-01B-11R-A13Y-07 1            2094          Stage IB2
# 11  TCGA-Q1-A73R-01A-11R-A33Z-07 0             567          Stage I
# 12  TCGA-EA-A6QX-01A-12R-A33Z-07 0             730          Stage IIIB
# 13  TCGA-C5-A905-01A-11R-A37O-07 0            4879          Stage IB
# 14  TCGA-VS-A957-01A-11R-A42T-07 0            1688          Stage IB1
# 249 TCGA-VS-A9UL-01A-11R-A42T-07 1             442          Stage IIIB
# 250 TCGA-VS-A9UV-01A-11R-A42T-07 1             104          Stage IVA
# 251 TCGA-MA-AA43-01A-11R-A42T-07 0             346          Stage IIIB
# 252 TCGA-VS-A9UJ-01A-11R-A42T-07 1              52          Stage IIB
# 253 TCGA-C5-A7CM-01A-11R-A33Z-07 0             619          Stage IB2
# 254 TCGA-EA-A3QD-01A-32R-A22U-07 0             397          Stage IIIB
# 255 TCGA-EA-A3HR-01A-11R-A213-07 0             940          Stage II
# 256 TCGA-VS-A8EK-01A-12R-A37O-07 1             829          Stage IVA
# 257 TCGA-VS-A9UM-01A-11R-A42T-07 1             829          Stage IVB
# 258 TCGA-C5-A1MN-01A-11R-A14Y-07 1            1245          Stage IIIB
# 259 TCGA-Q1-A6DT-01A-11R-A32P-07 1             275          Stage I
#     days_to_last_follow_up days_to_death age_at_diagnosis age_at_index height
# 1     NA                    570          16975            46            NA
# 2    854                     NA          10199            27            NA
# 3     50                     NA          14842            40           167
# 4    483                     NA          16450            45           173
# 5    186                    633          13253            36            NA
# 6     NA                   3046          24059            65           163
# 7   2114                     NA          16427            44            NA
# 8     NA                    157          17001            46           155
# 9    321                     NA          11692            32           157
# 10    NA                   2094          23727            64           149
# 11   567                     NA          16701            45           155
# 12   730                     NA          18035            49           154
# 13  4879                     NA          13584            37            NA
# 14  1688                     NA          23585            64           156
# 15   533                     NA          12644            34           168
# 16   959                     NA          13117            35           169
# 17    NA                   1394          14444            39           163
# 18  2394                     NA          18118            49           154
# 19   919                     NA          15848            43           163
# 20    NA                    370          16231            44            NA
# 21  1013                     NA          15909            43           162
# 22   448                     NA          17304            47           163
# 23    NA                    492          15319            41           160
# 24   607                     NA          17156            46           165
# 25    NA                    100          19423            53           163
# 26  3874                     NA          17954            49           155
# 27  3589                     NA          18839            51           163
# 28    NA                   2520          28815            78           171
# 29  1427                     NA          19454            53            NA
# 30    15                     NA          12207            33           165
# ⋮   ⋮                      ⋮             ⋮                ⋮            ⋮
# 230 4694                     NA          15777            43           161
# 231  834                     NA          13109            35           158
# 232    0                     NA          23879            65           150
# 233   NA                    350          18743            51           152
# 234   NA                    132          23334            63           161
# 235 1505                     NA          19473            53            NA
# 236   NA                   2859          16412            44            NA
# 237  406                     NA          19595            53           155
# 238 3039                     NA          11268            30            NA
# 239   NA                    284          25665            70           160
# 240  428                     NA          13601            37           152
# 241   NA                    414          26542            72           163
# 242 1535                     NA          21149            57           162
# 243  685                     NA          20066            54           155
# 244 5385                     NA          13297            36           151
# 245  636                     NA          13667            37           165
# 246  444                     NA          12607            34           165
# 247   NA                   1118          16792            45           165
# 248 1800                     NA          15374            42           159
# 249   NA                    442          29033            79           149
# 250   NA                    104          27348            74           152
# 251  346                     NA          17658            48           152
# 252   NA                     52          20264            55            NA
# 253  619                     NA          12853            35           168
# 254  397                     NA          21655            59           163
# 255  940                     NA          20980            57           146
# 256   NA                    829          23817            65           153
# 257   NA                    829          14255            39           160
# 258   NA                   1245          15499            42           165
# 259  103                    275          20286            55            NA
#     weight bmi      race                             ethnicity
# 1    76          NA white                            not reported
# 2    31          NA white                            not reported
# 3   105    37.64925 white                            not hispanic or latino
# 4    82    27.39818 white                            not hispanic or latino
# 5    NA          NA white                            not hispanic or latino
# 6    85    31.99217 white                            not hispanic or latino
# 7    64          NA white                            not hispanic or latino
# 8    45    18.73049 white                            not reported
# 9    69    27.99302 white                            not hispanic or latino
# 10   76    34.23269 white                            not reported
# 11   95    39.54214 white                            not reported
# 12   49    20.66116 asian                            not hispanic or latino
# 13   73          NA black or african american        not hispanic or latino
# 14   91    37.39316 white                            not reported
# 15   50    17.71542 white                            not hispanic or latino
# 16   54    18.90690 white                            not hispanic or latino
# 17   60    22.58271 white                            not hispanic or latino
# 18   74    31.20256 black or african american        not reported
# 19   75    28.22839 white                            not hispanic or latino
# 20   82          NA white                            not reported
# 21   68    25.91068 white                            not hispanic or latino
# 22   95    35.75596 white                            not hispanic or latino
# 23   63    24.60938 not reported                     hispanic or latino
# 24   86    31.58861 white                            not hispanic or latino
# 25   80    30.11028 american indian or alaska native hispanic or latino
# 26   89    37.04475 white                            not hispanic or latino
# 27   69    25.97012 white                            not hispanic or latino
# 28   56    19.15119 black or african american        not reported
# 29   NA          NA black or african american        not reported
# 30   73    26.81359 white                            not hispanic or latino
# ⋮   ⋮      ⋮        ⋮                                ⋮
# 230 104    40.12191 white                            not hispanic or latino
# 231 110    44.06345 american indian or alaska native hispanic or latino
# 232  83    36.88889 white                            hispanic or latino
# 233  90    38.95429 white                            not reported
# 234  52    20.06095 white                            not reported
# 235  NA          NA white                            not hispanic or latino
# 236 210          NA not reported                     not reported
# 237  58    24.14152 asian                            not hispanic or latino
# 238  NA          NA black or african american        not reported
# 239  79    30.85938 white                            not hispanic or latino
# 240  76    32.89474 not reported                     hispanic or latino
# 241  59    22.20633 black or african american        not hispanic or latino
# 242  74    28.19692 white                            not reported
# 243  84    34.96358 white                            hispanic or latino
# 244  82    35.96333 black or african american        not hispanic or latino
# 245  61    22.40588 white                            not hispanic or latino
# 246  86    31.58861 white                            not hispanic or latino
# 247  52    19.10009 white                            not hispanic or latino
# 248  68    26.89767 white                            not reported
# 249  56    25.22409 white                            not reported
# 250  31    13.41759 not reported                     not reported
# 251  72    31.16343 white                            hispanic or latino
# 252  NA          NA not reported                     not reported
# 253  75    26.57313 white                            hispanic or latino
# 254 105    39.51974 white                            not hispanic or latino
# 255  86    40.34528 white                            not hispanic or latino
# 256  50    21.35931 white                            not reported
# 257  75    29.29688 black or african american        not reported
# 258  64    23.50781 white                            not hispanic or latino
# 259  NA          NA white                            not hispanic or latino
