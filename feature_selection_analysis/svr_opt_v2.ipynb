# %%
import pandas as pd
import numpy as np
from time import perf_counter
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, KFold
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from skopt.space import Real, Integer, Categorical
from skopt import gp_minimize

import utils.dev_config as dev_conf
import utils.preprocessing as prep

# %%
dirs = dev_conf.get_dev_directories("../dev_paths.txt")
unified_dsets = ["unified_cervical_data", "unified_uterine_data", "unified_uterine_endometrial_data"]
matrisome_list = f"{dirs.data_dir}/matrisome/matrisome_hs_masterlist.tsv"

# %%
i = 0

# %%
matrisome_df = prep.load_matrisome_df(matrisome_list)

# %%
rand = np.random.RandomState()

# %% [markdown]
# # Load and filter survival data

# %%
event_code = {"Alive": 0, "Dead": 1}
covariate_cols = ["figo_stage", "age_at_diagnosis", "race", "ethnicity"]
dep_cols = ["vital_status", "survival_time"]
cat_cols = ["race", "ethnicity", "figo_chr"]
survival_df = prep.load_survival_df(f"{dirs.data_dir}/{unified_dsets[i]}/survival_data.tsv", event_code)

# %%
filtered_survival_df = (
    prep.decode_figo_stage(survival_df[["sample_name"] + dep_cols + covariate_cols].dropna(), to="c")
        .query("vital_status == 1")
        .drop(["vital_status"], axis=1)
        .pipe(pd.get_dummies, columns=cat_cols)
        .reset_index(drop = True)
)
filtered_survival_df.columns = filtered_survival_df.columns.str.replace(' ', '_')

print(filtered_survival_df.shape)
# filtered_survival_df.head()
# Out:
# (66, 16)

# %% [markdown]
# # Load normalized matrisome count data

# %%
norm_matrisome_counts_df = pd.read_csv(f"{dirs.data_dir}/{unified_dsets[i]}/norm_matrisome_counts.tsv", sep='\t')
norm_filtered_matrisome_counts_t_df = prep.transpose_df(
    norm_matrisome_counts_df[["geneID"] + list(filtered_survival_df.sample_name)], "geneID", "sample_name"
)
print(norm_filtered_matrisome_counts_t_df.shape)
# norm_filtered_matrisome_counts_t_df.head()
# Out:
# (66, 1009)

# %% [markdown]
# # Join survival and count data

# %%
joined_df = (
    pd.merge(filtered_survival_df, norm_filtered_matrisome_counts_t_df, on="sample_name")
        .set_index("sample_name")
)
print(joined_df.shape)
# joined_df.head()
# Out:
# (66, 1023)

# %%
rand.seed(123)
shuffled_df = joined_df.sample(frac=1, random_state=rand)
x_df = shuffled_df.iloc[:, 1:]
y_df = shuffled_df.iloc[:, [0]]

# %%
def objective(h_params, X, y):
    print(h_params)
    model = SVR(
        kernel=h_params[0],
        C=h_params[1],
        epsilon=h_params[2],
        gamma=h_params[3],
        degree=h_params[4],
        coef0=h_params[5]
    )
    # Standardize all variables (except one-hots)
    pipeline = make_pipeline(
        ColumnTransformer([
            ("standard", StandardScaler(), ["age_at_diagnosis"] + list(norm_filtered_matrisome_counts_t_df.columns[1:]))
        ], remainder="passthrough"),
        model
    )
    ttr = TransformedTargetRegressor(regressor=pipeline, transformer=StandardScaler())
    return -np.mean(cross_val_score(
        ttr,
        X,
        y,
        cv=KFold(n_splits=5),
        n_jobs=-1,
        scoring="neg_mean_absolute_error"
    ))

# %%
space = [
    Categorical(["linear", "rbf", "poly"], name="kernel"),
    Real(1e-1, 1e1, name="C"),
    Real(1e-3, 1e-1, name="epsilon"),
    Real(1e-3, 1e-1, name="gamma"),
    Integer(1, 3, name="degree"),
    Real(-1, 1, name="coef0")
]
n_initial = 20 * len(space[0].categories)
n_calls = 100 * len(space[0].categories)

# %%
def save_callback(res):
    # Does this model correspond with the best score seen so far?
    if res.func_vals[-1] == res.fun:
        h_param_df = pd.DataFrame({
            "param": res.space.dimension_names + ["loss_achieved"],
            "param_value": res.x + [res.fun]
        })
        h_param_df.to_csv("opt_svr_h_params.tsv", sep="\t", index=False)

# %%
res = gp_minimize(
    lambda h_ps: objective(h_ps, x_df, y_df),
    space,
    verbose=True,
    random_state=rand,
    n_initial_points=n_initial,
    n_calls = n_calls,
    n_jobs=-1,
    callback=save_callback
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# ['rbf', 4.860832066690728, 0.07997511248069224, 0.028987590498937163, 2, -0.9804853006583336]
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.0133
# Function value obtained: 565.4600
# Current minimum: 565.4600
# Iteration No: 2 started. Evaluating function at random point.
# ['poly', 6.923792863971573, 0.08706755969427699, 0.0275125783572481, 2, -0.4634373845765508]
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.6359
# Function value obtained: 648.8427
# Current minimum: 565.4600
# Iteration No: 3 started. Evaluating function at random point.
# ['rbf', 2.778095179642898, 0.05347613910877633, 0.018361893417211655, 2, 0.7822181916783213]
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.6714
# Function value obtained: 558.7666
# Current minimum: 558.7666
# Iteration No: 4 started. Evaluating function at random point.
# ['linear', 4.9937304017493425, 0.022017512235608248, 0.05256681000178573, 1, 0.8381136018546875]
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.6451
# Function value obtained: 628.0653
# Current minimum: 558.7666
# Iteration No: 5 started. Evaluating function at random point.
# ['rbf', 4.822770839816896, 0.031678467416180175, 0.05121322745633875, 2, 0.527673388950967]
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.2698
# Function value obtained: 561.6733
# Current minimum: 558.7666
# Iteration No: 6 started. Evaluating function at random point.
# ['linear', 5.165381702411964, 0.09106717036578019, 0.022619225341872183, 2, 0.7099456316481534]
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.1885
# Function value obtained: 628.7709
# Current minimum: 558.7666
# Iteration No: 7 started. Evaluating function at random point.
# ['poly', 3.9901496666040686, 0.02389884664991528, 0.03863729671702074, 2, 0.11343812935588504]
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.2185
# Function value obtained: 630.0127
# Current minimum: 558.7666
# Iteration No: 8 started. Evaluating function at random point.
# ['linear', 6.416422927001293, 0.006707153482172749, 0.00525966378657875, 3, -0.4148247927594738]
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.1603
# Function value obtained: 628.1097
# Current minimum: 558.7666
# Iteration No: 9 started. Evaluating function at random point.
# ['rbf', 3.74186606928866, 0.08747672431021698, 0.0039129496216463305, 2, -0.5195049922034897]
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.1623
# Function value obtained: 554.5188
# Current minimum: 554.5188
# Iteration No: 10 started. Evaluating function at random point.
# ['rbf', 4.6563604015818765, 0.02012386269721476, 0.030075557848606087, 3, 0.1189747510081205]
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.1854
# Function value obtained: 560.8642
# Current minimum: 554.5188
# Iteration No: 11 started. Evaluating function at random point.
# ['poly', 8.110354109907302, 0.08698864328814376, 0.04238125319095069, 1, -0.04308199059411755]
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.1599
# Function value obtained: 628.6487
# Current minimum: 554.5188
# Iteration No: 12 started. Evaluating function at random point.
# ['poly', 5.848256997489761, 0.03161070079554705, 0.09206837990020364, 2, -0.30151723015850995]
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.1810
# Function value obtained: 633.3408
# Current minimum: 554.5188
# Iteration No: 13 started. Evaluating function at random point.
# ['poly', 4.5456286173172336, 0.028949775101909235, 0.030291775996830004, 2, 0.43038255817233106]
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.2436
# Function value obtained: 626.6382
# Current minimum: 554.5188
# Iteration No: 14 started. Evaluating function at random point.
# ['poly', 3.5852141030450433, 0.06364510700386934, 0.08743878299702582, 1, 0.9749566445628477]
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.2063
# Function value obtained: 628.1494
# Current minimum: 554.5188
# Iteration No: 15 started. Evaluating function at random point.
# ['poly', 8.279430762572002, 0.007480692650425288, 0.0015299755502472946, 3, 0.8226362697446883]
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.1546
# Function value obtained: 619.6193
# Current minimum: 554.5188
# Iteration No: 16 started. Evaluating function at random point.
# ['linear', 0.37275871141941563, 0.08191615704321, 0.02494093426563867, 1, -0.8648783303271832]
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.1588
# Function value obtained: 628.5505
# Current minimum: 554.5188
# Iteration No: 17 started. Evaluating function at random point.
# ['poly', 5.143349688358102, 0.0422627188426334, 0.02632845010671833, 2, 0.6147688743620807]
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.2093
# Function value obtained: 625.1278
# Current minimum: 554.5188
# Iteration No: 18 started. Evaluating function at random point.
# ['rbf', 6.893249912068624, 0.09926874897525377, 0.041113332696466345, 1, -0.023651020409810597]
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.1994
# Function value obtained: 567.2645
# Current minimum: 554.5188
# Iteration No: 19 started. Evaluating function at random point.
# ['poly', 4.093212712252483, 0.018928447033339915, 0.005754950297955516, 2, -0.468177585528729]
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.1610
# Function value obtained: 39297.5306
# Current minimum: 554.5188
# Iteration No: 20 started. Evaluating function at random point.
# ['rbf', 5.88205655416066, 0.04826858789004068, 0.017979987441227446, 1, -0.6859295431664016]
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.2225
# Function value obtained: 562.8669
# Current minimum: 554.5188
# Iteration No: 21 started. Evaluating function at random point.
# ['poly', 4.462365387257745, 0.06870046886860967, 0.02138130050397595, 2, 0.8489432205055836]
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 0.2298
# Function value obtained: 625.0052
# Current minimum: 554.5188
# Iteration No: 22 started. Evaluating function at random point.
# ['linear', 4.905428575503187, 0.07015779945655534, 0.009075279787230335, 3, -0.13378864344591568]
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 0.2086
# Function value obtained: 628.3174
# Current minimum: 554.5188
# Iteration No: 23 started. Evaluating function at random point.
# ['poly', 5.007830671483868, 0.03770148604609646, 0.09229073744256709, 3, 0.3110518388687482]
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 0.0794
# Function value obtained: 676.3604
# Current minimum: 554.5188
# Iteration No: 24 started. Evaluating function at random point.
# ['poly', 5.6936119881535845, 0.04296763518753259, 0.029532983497217287, 2, 0.3814764569458955]
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 0.0657
# Function value obtained: 628.5970
# Current minimum: 554.5188
# Iteration No: 25 started. Evaluating function at random point.
# ['rbf', 5.964676618541878, 0.04718573562940654, 0.06769233859876757, 2, 0.4042087364458198]
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 0.1015
# Function value obtained: 562.7783
# Current minimum: 554.5188
# Iteration No: 26 started. Evaluating function at random point.
# ['rbf', 0.9960477833529339, 0.006754388434314147, 0.0592137244761925, 3, 0.022634782996387992]
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.0871
# Function value obtained: 532.6993
# Current minimum: 532.6993
# Iteration No: 27 started. Evaluating function at random point.
# ['rbf', 3.109244575562755, 0.04980727052283004, 0.09795667389676435, 2, -0.6208656501961262]
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 0.0771
# Function value obtained: 560.0043
# Current minimum: 532.6993
# Iteration No: 28 started. Evaluating function at random point.
# ['poly', 3.506708060227729, 0.06827349854816016, 0.006327684593361618, 3, 0.20590037586270138]
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 0.0704
# Function value obtained: 672.4917
# Current minimum: 532.6993
# Iteration No: 29 started. Evaluating function at random point.
# ['poly', 7.501831910389268, 0.05402699143671853, 0.01180649170215738, 2, -0.6553147447581242]
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 0.0762
# Function value obtained: 707.6283
# Current minimum: 532.6993
# Iteration No: 30 started. Evaluating function at random point.
# ['poly', 5.345269591389848, 0.0628972023271145, 0.03219915924757285, 2, 0.6402840770384604]
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 0.0629
# Function value obtained: 628.5765
# Current minimum: 532.6993
# Iteration No: 31 started. Evaluating function at random point.
# ['linear', 1.3009638745020584, 0.045175278168817924, 0.0050524795202264, 2, -0.18121917481388294]
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.0769
# Function value obtained: 628.0210
# Current minimum: 532.6993
# Iteration No: 32 started. Evaluating function at random point.
# ['poly', 3.465704695938258, 0.08144443833389119, 0.05329234708104005, 2, -0.7655863242609884]
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 0.0677
# Function value obtained: 646.3083
# Current minimum: 532.6993
# Iteration No: 33 started. Evaluating function at random point.
# ['rbf', 4.402403231817012, 0.008645050068250127, 0.01899934145606285, 2, -0.041331658634087054]
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 0.0784
# Function value obtained: 560.0724
# Current minimum: 532.6993
# Iteration No: 34 started. Evaluating function at random point.
# ['poly', 1.086725170229216, 0.06005871374619441, 0.0255688188515112, 2, -0.3897727070671352]
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 0.0680
# Function value obtained: 644.4398
# Current minimum: 532.6993
# Iteration No: 35 started. Evaluating function at random point.
# ['rbf', 5.861951745884073, 0.07153675018567061, 0.06867793201417123, 3, 0.8264625112251318]
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 0.0785
# Function value obtained: 564.7696
# Current minimum: 532.6993
# Iteration No: 36 started. Evaluating function at random point.
# ['linear', 3.865123282877666, 0.056821797663795165, 0.014124800305141332, 2, -0.35486450472456343]
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 0.0748
# Function value obtained: 628.0350
# Current minimum: 532.6993
# Iteration No: 37 started. Evaluating function at random point.
# ['rbf', 5.799091602128371, 0.06334303577065768, 0.04070021536059518, 2, -0.19762814995234068]
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 0.0758
# Function value obtained: 564.1100
# Current minimum: 532.6993
# Iteration No: 38 started. Evaluating function at random point.
# ['rbf', 9.826069232975092, 0.017643559953978, 0.04798487368255532, 2, -0.12778532068204163]
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 0.0740
# Function value obtained: 560.6914
# Current minimum: 532.6993
# Iteration No: 39 started. Evaluating function at random point.
# ['poly', 3.9962810274909923, 0.0839700316777211, 0.06551261354681659, 3, -0.04599954519923832]
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 0.0801
# Function value obtained: 682.8303
# Current minimum: 532.6993
# Iteration No: 40 started. Evaluating function at random point.
# ['rbf', 7.9428570496953075, 0.027270394870143894, 0.07648138912243108, 3, -0.29401525916889704]
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 0.0745
# Function value obtained: 561.3639
# Current minimum: 532.6993
# Iteration No: 41 started. Evaluating function at random point.
# ['rbf', 6.78481022150443, 0.07023858514606811, 0.046500095472086986, 1, 0.9959603539113557]
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 0.0688
# Function value obtained: 564.6657
# Current minimum: 532.6993
# Iteration No: 42 started. Evaluating function at random point.
# ['poly', 0.7747105715866603, 0.015467566693338586, 0.08405241410473142, 2, 0.07890194238997061]
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 0.0756
# Function value obtained: 629.8696
# Current minimum: 532.6993
# Iteration No: 43 started. Evaluating function at random point.
# ['linear', 5.706832680402253, 0.03688600621614116, 0.03250315043059982, 2, -0.2901939967280637]
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 0.1083
# Function value obtained: 628.0204
# Current minimum: 532.6993
# Iteration No: 44 started. Evaluating function at random point.
# ['poly', 6.319986757875139, 0.09678362170340518, 0.028860334854082976, 1, -0.8449632910098606]
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 0.0759
# Function value obtained: 628.9154
# Current minimum: 532.6993
# Iteration No: 45 started. Evaluating function at random point.
# ['rbf', 0.4419956857731301, 0.04965604175747844, 0.001089551410652579, 3, -0.3212050571954038]
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 0.0779
# Function value obtained: 497.6901
# Current minimum: 497.6901
# Iteration No: 46 started. Evaluating function at random point.
# ['poly', 3.3739948232531662, 0.08900998411937093, 0.07320291663436744, 1, 0.4134024144229129]
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 0.0771
# Function value obtained: 628.7235
# Current minimum: 497.6901
# Iteration No: 47 started. Evaluating function at random point.
# ['rbf', 5.451324400200064, 0.09759735355998951, 0.04753031994473021, 1, 0.026978699925929384]
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 0.0785
# Function value obtained: 567.0970
# Current minimum: 497.6901
# Iteration No: 48 started. Evaluating function at random point.
# ['poly', 5.837022666918768, 0.0838878256545875, 0.035725468714587816, 3, -0.1991757787049251]
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 0.0798
# Function value obtained: 684.0100
# Current minimum: 497.6901
# Iteration No: 49 started. Evaluating function at random point.
# ['poly', 4.082421573981466, 0.011295185847797748, 0.047126788160898526, 2, -0.40461239763143564]
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 0.0717
# Function value obtained: 634.3326
# Current minimum: 497.6901
# Iteration No: 50 started. Evaluating function at random point.
# ['rbf', 4.837852450017183, 0.02895391782594929, 0.042435447792581404, 2, 0.542615858052728]
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 0.0854
# Function value obtained: 561.4819
# Current minimum: 497.6901
# Iteration No: 51 started. Evaluating function at random point.
# ['poly', 4.784945765119179, 0.05068783869469012, 0.08373086492909694, 2, 0.02118479164024234]
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 0.0815
# Function value obtained: 633.6890
# Current minimum: 497.6901
# Iteration No: 52 started. Evaluating function at random point.
# ['poly', 3.409676261340398, 0.05465497140355623, 0.058425180308927294, 1, 0.3588720439573485]
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 0.0830
# Function value obtained: 627.9956
# Current minimum: 497.6901
# Iteration No: 53 started. Evaluating function at random point.
# ['poly', 5.569556045781851, 0.050991322759720216, 0.009189235213654352, 2, 0.25786866746599113]
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 0.0813
# Function value obtained: 625.1336
# Current minimum: 497.6901
# Iteration No: 54 started. Evaluating function at random point.
# ['poly', 7.254749227095013, 0.009354454988994298, 0.09807418991245785, 1, -0.7769007273510453]
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 0.0755
# Function value obtained: 628.0939
# Current minimum: 497.6901
# Iteration No: 55 started. Evaluating function at random point.
# ['poly', 4.505351094782152, 0.019067483374750966, 0.042633337654386094, 3, 0.5114439165216422]
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 0.0714
# Function value obtained: 671.8235
# Current minimum: 497.6901
# Iteration No: 56 started. Evaluating function at random point.
# ['linear', 1.873423978996288, 0.05559559062960516, 0.05666974414523621, 2, -0.27886992388510523]
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 0.0840
# Function value obtained: 628.0289
# Current minimum: 497.6901
# Iteration No: 57 started. Evaluating function at random point.
# ['poly', 4.175419092988538, 0.003916242307636715, 0.006342788231348694, 1, 0.25694115976683385]
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 0.0770
# Function value obtained: 628.1013
# Current minimum: 497.6901
# Iteration No: 58 started. Evaluating function at random point.
# ['poly', 1.3781014923958912, 0.03779194681903311, 0.07762796047837996, 2, -0.8649268683612339]
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 0.0799
# Function value obtained: 639.0310
# Current minimum: 497.6901
# Iteration No: 59 started. Evaluating function at random point.
# ['poly', 3.2661370901238156, 0.09806973467149431, 0.01649919790551364, 1, -0.032549808705577776]
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 0.0780
# Function value obtained: 628.9392
# Current minimum: 497.6901
# Iteration No: 60 started. Evaluating function at random point.
# ['poly', 0.770672258957021, 0.05288866341862375, 0.08254734587598606, 2, 0.16238033825640907]
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 1.5421
# Function value obtained: 633.3453
# Current minimum: 497.6901
# Iteration No: 61 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.1, 0.1, 3, -1.0]
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 2.8497
# Function value obtained: 567.3378
# Current minimum: 497.6901
# Iteration No: 62 started. Searching for the next optimal point.
# ['rbf', 4.756773466900024, 0.0035630188151159, 0.024889790578252007, 2, 0.256763987324782]
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 1.8327
# Function value obtained: 559.7286
# Current minimum: 497.6901
# Iteration No: 63 started. Searching for the next optimal point.
# ['linear', 5.337709547974841, 0.02217915653892629, 0.058557000375898276, 2, -0.23531618728090709]
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 1.6942
# Function value obtained: 628.0670
# Current minimum: 497.6901
# Iteration No: 64 started. Searching for the next optimal point.
# ['poly', 7.714811443840004, 0.017031587060642412, 0.0656404756101475, 2, 0.9470297519936768]
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 2.2596
# Function value obtained: 625.2384
# Current minimum: 497.6901
# Iteration No: 65 started. Searching for the next optimal point.
# ['linear', 9.568089625454162, 0.037289750820127636, 0.03376178322853362, 3, -0.17934355303691352]
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 1.3235
# Function value obtained: 628.0480
# Current minimum: 497.6901
# Iteration No: 66 started. Searching for the next optimal point.
# ['rbf', 5.137521563837271, 0.008169250594879295, 0.019682087778874587, 2, -0.4015440317593716]
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 1.7400
# Function value obtained: 560.0405
# Current minimum: 497.6901
# Iteration No: 67 started. Searching for the next optimal point.
# ['poly', 8.130732717411094, 0.0913012525491122, 0.05010689675397358, 2, -0.46303832514383136]
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 2.9503
# Function value obtained: 644.0815
# Current minimum: 497.6901
# Iteration No: 68 started. Searching for the next optimal point.
# ['poly', 2.442087501623845, 0.004994676861083501, 0.0186265138347537, 3, -0.4106490014086991]
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 1.5043
# Function value obtained: 678.6565
# Current minimum: 497.6901
# Iteration No: 69 started. Searching for the next optimal point.
# ['poly', 4.675049786962349, 0.012298214096236288, 0.08036814668209985, 2, -0.40064492801886586]
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 1.5235
# Function value obtained: 632.2078
# Current minimum: 497.6901
# Iteration No: 70 started. Searching for the next optimal point.
# ['poly', 8.105837891342999, 0.006239955719229497, 0.0017293199336756845, 3, 1.0]
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 1.1458
# Function value obtained: 619.0289
# Current minimum: 497.6901
# Iteration No: 71 started. Searching for the next optimal point.
# ['poly', 3.2405002708053035, 0.09177405816061378, 0.013063020912245853, 2, -0.520409609378335]
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 1.4681
# Function value obtained: 670.5866
# Current minimum: 497.6901
# Iteration No: 72 started. Searching for the next optimal point.
# ['poly', 4.065944605411696, 0.02422307548694788, 0.04208520994206928, 2, 0.16348715468224162]
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 2.1991
# Function value obtained: 629.6964
# Current minimum: 497.6901
# Iteration No: 73 started. Searching for the next optimal point.
# ['poly', 7.455547555679253, 0.04867389336444139, 0.046361296040247364, 3, -0.3200383646575472]
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 1.8899
# Function value obtained: 680.2509
# Current minimum: 497.6901
# Iteration No: 74 started. Searching for the next optimal point.
# ['rbf', 4.651410691856496, 0.019883082142992232, 0.033044480204351405, 3, 0.3269490569410538]
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 1.7639
# Function value obtained: 560.8474
# Current minimum: 497.6901
# Iteration No: 75 started. Searching for the next optimal point.
# ['poly', 0.6809721682753627, 0.05127632535638959, 0.0284222443539802, 3, -0.3231207902904075]
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 1.9094
# Function value obtained: 681.6247
# Current minimum: 497.6901
# Iteration No: 76 started. Searching for the next optimal point.
# ['poly', 3.9283401469921695, 0.019109544085749712, 0.0454492419730591, 3, 0.41039300236980525]
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 2.2248
# Function value obtained: 672.6254
# Current minimum: 497.6901
# Iteration No: 77 started. Searching for the next optimal point.
# ['rbf', 9.790536042984161, 0.01764009924758214, 0.04984276565971905, 2, -0.10863555719270512]
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 3.1925
# Function value obtained: 560.6911
# Current minimum: 497.6901
# Iteration No: 78 started. Searching for the next optimal point.
# ['poly', 4.694789750873696, 0.029301369177330984, 0.032486875290575985, 2, 0.5283999560829018]
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 1.9962
# Function value obtained: 625.9702
# Current minimum: 497.6901
# Iteration No: 79 started. Searching for the next optimal point.
# ['rbf', 5.407639589221024, 0.007706604875841434, 0.02132149032919894, 2, 0.41529898843220625]
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 1.3279
# Function value obtained: 560.0094
# Current minimum: 497.6901
# Iteration No: 80 started. Searching for the next optimal point.
# ['rbf', 0.8749378025578448, 0.03756395717929017, 0.0908287748465555, 2, 0.5280705395152638]
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 1.7495
# Function value obtained: 531.7057
# Current minimum: 497.6901
# Iteration No: 81 started. Searching for the next optimal point.
# ['rbf', 9.06352796720606, 0.04810203077732126, 0.001, 3, -0.31936105934525494]
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 1.4500
# Function value obtained: 543.0496
# Current minimum: 497.6901
# Iteration No: 82 started. Searching for the next optimal point.
# ['linear', 0.3236940006984582, 0.06885379077985293, 0.0010714257409213854, 2, -0.37802207400692567]
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 3.4166
# Function value obtained: 628.2822
# Current minimum: 497.6901
# Iteration No: 83 started. Searching for the next optimal point.
# ['poly', 10.0, 0.01516580966781558, 0.06756593908728847, 2, 1.0]
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 1.8998
# Function value obtained: 624.9017
# Current minimum: 497.6901
# Iteration No: 84 started. Searching for the next optimal point.
# ['rbf', 1.9954818680685107, 0.009005436724847552, 0.02387952120624039, 2, 1.0]
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 1.2443
# Function value obtained: 547.3226
# Current minimum: 497.6901
# Iteration No: 85 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.021224275826518188, 0.01214507401561514, 3, -0.2865442149979036]
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 1.4845
# Function value obtained: 523.5045
# Current minimum: 497.6901
# Iteration No: 86 started. Searching for the next optimal point.
# ['rbf', 5.402527908946938, 0.001, 0.0018533083800745496, 2, 0.9965070118287283]
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 3.2964
# Function value obtained: 524.7480
# Current minimum: 497.6901
# Iteration No: 87 started. Searching for the next optimal point.
# ['poly', 2.090838539952438, 0.05342040173404577, 0.007872214355236981, 2, 1.0]
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 2.7010
# Function value obtained: 619.0695
# Current minimum: 497.6901
# Iteration No: 88 started. Searching for the next optimal point.
# ['poly', 0.4864352070924941, 0.0038508493557895505, 0.011562279690168827, 1, -1.0]
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 1.6187
# Function value obtained: 582.5087
# Current minimum: 497.6901
# Iteration No: 89 started. Searching for the next optimal point.
# ['rbf', 1.465557256567672, 0.09462072294595526, 0.08370873322378639, 1, -0.004815789933147574]
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 1.8322
# Function value obtained: 544.4185
# Current minimum: 497.6901
# Iteration No: 90 started. Searching for the next optimal point.
# ['rbf', 4.197663027886612, 0.027522984486986417, 0.036452496107952814, 2, 0.23406722431208316]
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 2.5081
# Function value obtained: 561.3625
# Current minimum: 497.6901
# Iteration No: 91 started. Searching for the next optimal point.
# ['poly', 3.058201220127858, 0.019973628561329677, 0.04423488604448038, 2, -0.44478564545208255]
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 2.8121
# Function value obtained: 636.3034
# Current minimum: 497.6901
# Iteration No: 92 started. Searching for the next optimal point.
# ['poly', 3.3342828359428913, 0.007914579832337962, 0.020460655191748386, 2, -0.3988128351544402]
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 1.4769
# Function value obtained: 642.6652
# Current minimum: 497.6901
# Iteration No: 93 started. Searching for the next optimal point.
# ['rbf', 5.2725689875858865, 0.02025451625691058, 0.04718101587010322, 2, -0.02457437282648056]
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 2.0223
# Function value obtained: 560.8734
# Current minimum: 497.6901
# Iteration No: 94 started. Searching for the next optimal point.
# ['rbf', 4.930565533440688, 0.002948220875962129, 0.024615378462755723, 2, 1.0]
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 1.8921
# Function value obtained: 559.6866
# Current minimum: 497.6901
# Iteration No: 95 started. Searching for the next optimal point.
# ['linear', 3.9610498355478367, 0.02209898728633224, 0.06760355531041481, 2, -1.0]
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 3.4044
# Function value obtained: 628.0506
# Current minimum: 497.6901
# Iteration No: 96 started. Searching for the next optimal point.
# ['linear', 3.851610866676819, 0.04564626589468976, 0.014724495367208962, 2, 0.5692292019452516]
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 2.0536
# Function value obtained: 628.0219
# Current minimum: 497.6901
# Iteration No: 97 started. Searching for the next optimal point.
# ['poly', 1.7298376764891688, 0.03641271034412314, 0.004055672124966807, 2, -0.5216849232073073]
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 2.8289
# Function value obtained: 17242.7946
# Current minimum: 497.6901
# Iteration No: 98 started. Searching for the next optimal point.
# ['rbf', 8.440199941159761, 0.020299673800115835, 0.05724247005760045, 2, -0.4430446194439569]
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 3.1770
# Function value obtained: 560.8765
# Current minimum: 497.6901
# Iteration No: 99 started. Searching for the next optimal point.
# ['poly', 7.167290198571555, 0.006387577643261193, 0.008988016478121964, 1, -0.14281450629476045]
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 2.4030
# Function value obtained: 628.0859
# Current minimum: 497.6901
# Iteration No: 100 started. Searching for the next optimal point.
# ['poly', 2.506545426876721, 0.007369460177743376, 0.021420787808724973, 2, -0.41117903071992234]
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.6783
# Function value obtained: 642.3429
# Current minimum: 497.6901
# Iteration No: 101 started. Searching for the next optimal point.
# ['linear', 1.2222322381074167, 0.04641419636237964, 0.005425099733674379, 2, 0.11640161510025693]
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 2.2441
# Function value obtained: 628.0106
# Current minimum: 497.6901
# Iteration No: 102 started. Searching for the next optimal point.
# ['linear', 7.908470562017763, 0.037207397500888674, 0.03519622767637507, 2, -0.27289967883674193]
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 4.0334
# Function value obtained: 628.0576
# Current minimum: 497.6901
# Iteration No: 103 started. Searching for the next optimal point.
# ['rbf', 8.50121940963623, 0.001, 0.005240053862402739, 2, 0.4927219992856047]
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 3.2896
# Function value obtained: 555.5429
# Current minimum: 497.6901
# Iteration No: 104 started. Searching for the next optimal point.
# ['rbf', 4.535488602004816, 0.02978660272441552, 0.04808320301670587, 2, 0.730805187327378]
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 2.8996
# Function value obtained: 561.5404
# Current minimum: 497.6901
# Iteration No: 105 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.05375998976190555, 0.02401097479296365, 2, 1.0]
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 3.8387
# Function value obtained: 524.1400
# Current minimum: 497.6901
# Iteration No: 106 started. Searching for the next optimal point.
# ['rbf', 0.728210947014468, 0.049953706678984154, 0.001, 3, -0.5502675292350878]
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 1.9428
# Function value obtained: 495.5320
# Current minimum: 495.5320
# Iteration No: 107 started. Searching for the next optimal point.
# ['rbf', 9.351505139109992, 0.00760828503446544, 0.02896192992772519, 2, 1.0]
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 2.4191
# Function value obtained: 560.0028
# Current minimum: 495.5320
# Iteration No: 108 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.05016153767016939, 0.0010983850556469945, 3, -0.6378246526913625]
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 1.9094
# Function value obtained: 511.2174
# Current minimum: 495.5320
# Iteration No: 109 started. Searching for the next optimal point.
# ['rbf', 1.6491260203224678, 0.05314808425133854, 0.001, 2, 1.0]
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 4.2692
# Function value obtained: 499.7398
# Current minimum: 495.5320
# Iteration No: 110 started. Searching for the next optimal point.
# ['poly', 0.9940962515642215, 0.020324665750791383, 0.047231971145580566, 2, -0.4430569167814793]
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 2.2460
# Function value obtained: 635.8753
# Current minimum: 495.5320
# Iteration No: 111 started. Searching for the next optimal point.
# ['rbf', 4.615557767916244, 0.050594168672103056, 0.05010275117509032, 2, -0.5509785090322564]
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 3.1131
# Function value obtained: 563.0635
# Current minimum: 495.5320
# Iteration No: 112 started. Searching for the next optimal point.
# ['poly', 0.8120905107230836, 0.0707072273624466, 0.006378206984275522, 3, 0.25273263746157193]
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 3.0156
# Function value obtained: 670.9083
# Current minimum: 495.5320
# Iteration No: 113 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.05064193426636922, 0.0616948891011247, 2, 1.0]
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 2.1167
# Function value obtained: 524.1014
# Current minimum: 495.5320
# Iteration No: 114 started. Searching for the next optimal point.
# ['poly', 4.1568095655237896, 0.07271020607232873, 0.024595745576632733, 2, 0.9483326455537406]
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 2.3126
# Function value obtained: 625.6020
# Current minimum: 495.5320
# Iteration No: 115 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.06049754280179598, 0.001, 2, 1.0]
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 3.6423
# Function value obtained: 510.6541
# Current minimum: 495.5320
# Iteration No: 116 started. Searching for the next optimal point.
# ['rbf', 1.3140460651871866, 0.026605345876337054, 0.0416329758594438, 3, 0.009293629520064517]
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 2.5338
# Function value obtained: 537.9909
# Current minimum: 495.5320
# Iteration No: 117 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.03200285822335074, 0.06000169510426826, 2, 1.0]
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 4.0903
# Function value obtained: 561.6964
# Current minimum: 495.5320
# Iteration No: 118 started. Searching for the next optimal point.
# ['linear', 4.10989592334345, 0.07053726081972003, 0.03218490000449304, 3, -0.16066950400964575]
# Iteration No: 118 ended. Search finished for the next optimal point.
# Time taken: 3.2924
# Function value obtained: 628.3153
# Current minimum: 495.5320
# Iteration No: 119 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.04212796735848002, 0.0982181794381266, 2, 1.0]
# Iteration No: 119 ended. Search finished for the next optimal point.
# Time taken: 2.1449
# Function value obtained: 562.4096
# Current minimum: 495.5320
# Iteration No: 120 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.06767770534092632, 0.0453379674684335, 2, 1.0]
# Iteration No: 120 ended. Search finished for the next optimal point.
# Time taken: 2.2305
# Function value obtained: 524.2551
# Current minimum: 495.5320
# Iteration No: 121 started. Searching for the next optimal point.
# ['rbf', 4.084176925750462, 0.053823841306172356, 0.001, 2, 1.0]
# Iteration No: 121 ended. Search finished for the next optimal point.
# Time taken: 3.6544
# Function value obtained: 532.2953
# Current minimum: 495.5320
# Iteration No: 122 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.06197217168206052, 0.0016373064750128466, 2, 0.8012265780061636]
# Iteration No: 122 ended. Search finished for the next optimal point.
# Time taken: 2.9681
# Function value obtained: 514.0376
# Current minimum: 495.5320
# Iteration No: 123 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.04789617275587675, 0.05812560827538658, 2, 1.0]
# Iteration No: 123 ended. Search finished for the next optimal point.
# Time taken: 3.0540
# Function value obtained: 562.8356
# Current minimum: 495.5320
# Iteration No: 124 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.0025033262611884096, 0.030904313315395584, 2, 1.0]
# Iteration No: 124 ended. Search finished for the next optimal point.
# Time taken: 3.6217
# Function value obtained: 522.8542
# Current minimum: 495.5320
# Iteration No: 125 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.0111321024232282, 0.06653049097440922, 3, -0.18722839182839834]
# Iteration No: 125 ended. Search finished for the next optimal point.
# Time taken: 2.5885
# Function value obtained: 523.1221
# Current minimum: 495.5320
# Iteration No: 126 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.052664694705772244, 0.001, 2, 1.0]
# Iteration No: 126 ended. Search finished for the next optimal point.
# Time taken: 2.2926
# Function value obtained: 510.8732
# Current minimum: 495.5320
# Iteration No: 127 started. Searching for the next optimal point.
# ['poly', 2.540003115964717, 0.05291105842135214, 0.008000592777789403, 2, 0.697962572523809]
# Iteration No: 127 ended. Search finished for the next optimal point.
# Time taken: 3.5301
# Function value obtained: 618.8333
# Current minimum: 495.5320
# Iteration No: 128 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.02664188685163294, 0.03477536717316404, 2, 1.0]
# Iteration No: 128 ended. Search finished for the next optimal point.
# Time taken: 4.3552
# Function value obtained: 561.3199
# Current minimum: 495.5320
# Iteration No: 129 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.08273611524815325, 0.001, 2, 1.0]
# Iteration No: 129 ended. Search finished for the next optimal point.
# Time taken: 4.7572
# Function value obtained: 510.0571
# Current minimum: 495.5320
# Iteration No: 130 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.07143702989004347, 0.041476390376896585, 2, 1.0]
# Iteration No: 130 ended. Search finished for the next optimal point.
# Time taken: 2.8437
# Function value obtained: 524.3367
# Current minimum: 495.5320
# Iteration No: 131 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.03171089708928306, 0.04929866862507594, 3, 1.0]
# Iteration No: 131 ended. Search finished for the next optimal point.
# Time taken: 2.5100
# Function value obtained: 523.7009
# Current minimum: 495.5320
# Iteration No: 132 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.025841455157672947, 0.06305660416128979, 3, -0.3501479292384807]
# Iteration No: 132 ended. Search finished for the next optimal point.
# Time taken: 6.1510
# Function value obtained: 523.6232
# Current minimum: 495.5320
# Iteration No: 133 started. Searching for the next optimal point.
# ['poly', 6.325826932179843, 0.09046114978640946, 0.012520287817088041, 2, -0.5174600363090581]
# Iteration No: 133 ended. Search finished for the next optimal point.
# Time taken: 3.8913
# Function value obtained: 671.8674
# Current minimum: 495.5320
# Iteration No: 134 started. Searching for the next optimal point.
# ['poly', 8.014413410633445, 0.030421556394843542, 0.00955748640024989, 2, 0.18791603528260037]
# Iteration No: 134 ended. Search finished for the next optimal point.
# Time taken: 5.3843
# Function value obtained: 624.9602
# Current minimum: 495.5320
# Iteration No: 135 started. Searching for the next optimal point.
# ['rbf', 8.58331385491206, 0.08497700936731084, 0.04623435608238489, 2, -0.45809545796253237]
# Iteration No: 135 ended. Search finished for the next optimal point.
# Time taken: 2.6369
# Function value obtained: 565.8961
# Current minimum: 495.5320
# Iteration No: 136 started. Searching for the next optimal point.
# ['poly', 9.414685210348951, 0.030102835371047913, 0.012270450748456077, 2, 0.5474169144813203]
# Iteration No: 136 ended. Search finished for the next optimal point.
# Time taken: 2.5903
# Function value obtained: 620.1075
# Current minimum: 495.5320
# Iteration No: 137 started. Searching for the next optimal point.
# ['linear', 2.089884600220898, 0.03569795339242595, 0.03502816799019104, 2, -0.4631145144552199]
# Iteration No: 137 ended. Search finished for the next optimal point.
# Time taken: 5.6460
# Function value obtained: 628.0432
# Current minimum: 495.5320
# Iteration No: 138 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.021216498774261645, 0.061971433284377486, 2, 1.0]
# Iteration No: 138 ended. Search finished for the next optimal point.
# Time taken: 2.6244
# Function value obtained: 560.9406
# Current minimum: 495.5320
# Iteration No: 139 started. Searching for the next optimal point.
# ['poly', 0.1, 0.002065181554482638, 0.010886616214553248, 3, 0.011981283154380185]
# Iteration No: 139 ended. Search finished for the next optimal point.
# Time taken: 3.5059
# Function value obtained: 672.6601
# Current minimum: 495.5320
# Iteration No: 140 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.019221005606910944, 0.0470574825575836, 2, 0.5857337696904015]
# Iteration No: 140 ended. Search finished for the next optimal point.
# Time taken: 3.8207
# Function value obtained: 560.8011
# Current minimum: 495.5320
# Iteration No: 141 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.014702939288901585, 0.05188358756918196, 2, 0.3992649910292265]
# Iteration No: 141 ended. Search finished for the next optimal point.
# Time taken: 4.1297
# Function value obtained: 560.4868
# Current minimum: 495.5320
# Iteration No: 142 started. Searching for the next optimal point.
# ['rbf', 2.3340762047455113, 0.05228794159096839, 0.021799664446037433, 2, 1.0]
# Iteration No: 142 ended. Search finished for the next optimal point.
# Time taken: 4.1091
# Function value obtained: 554.1438
# Current minimum: 495.5320
# Iteration No: 143 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.03153229077068675, 0.07381531178251213, 2, -0.9146098796910435]
# Iteration No: 143 ended. Search finished for the next optimal point.
# Time taken: 3.1504
# Function value obtained: 561.6630
# Current minimum: 495.5320
# Iteration No: 144 started. Searching for the next optimal point.
# ['rbf', 1.7039784392198276, 0.07505712624947028, 0.0013778048001258027, 3, -0.3262755647194464]
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 2.7889
# Function value obtained: 502.4699
# Current minimum: 495.5320
# Iteration No: 145 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.0851312249040702, 0.0014105498920793335, 3, 1.0]
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 4.2085
# Function value obtained: 512.3042
# Current minimum: 495.5320
# Iteration No: 146 started. Searching for the next optimal point.
# ['rbf', 4.799255429100761, 0.039079397703455705, 0.06116084613446637, 2, 0.9690822032269746]
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 3.8016
# Function value obtained: 562.1932
# Current minimum: 495.5320
# Iteration No: 147 started. Searching for the next optimal point.
# ['rbf', 4.347843242849078, 0.0398208142435053, 0.06563390443230407, 2, 0.8227596185402777]
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 4.1957
# Function value obtained: 562.2449
# Current minimum: 495.5320
# Iteration No: 148 started. Searching for the next optimal point.
# ['poly', 6.238150270451782, 0.006836731894770026, 0.00917322449882254, 1, -0.1153022054105236]
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 2.7630
# Function value obtained: 628.1038
# Current minimum: 495.5320
# Iteration No: 149 started. Searching for the next optimal point.
# ['rbf', 3.814967844292435, 0.0757792330822889, 0.001734294597822523, 3, -0.7550751930655186]
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 5.2491
# Function value obtained: 529.2422
# Current minimum: 495.5320
# Iteration No: 150 started. Searching for the next optimal point.
# ['rbf', 7.9115823128107, 0.03765183200546391, 0.09867469588122545, 2, 0.8402535566116613]
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 4.4901
# Function value obtained: 562.0924
# Current minimum: 495.5320
# Iteration No: 151 started. Searching for the next optimal point.
# ['rbf', 0.324333932217686, 0.034235897994011215, 0.067226151595953, 3, 0.30396926531776636]
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 5.3882
# Function value obtained: 525.9425
# Current minimum: 495.5320
# Iteration No: 152 started. Searching for the next optimal point.
# ['rbf', 7.862160177309984, 0.015267523600902153, 0.06666962714691078, 2, 0.9780231369425356]
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 2.9909
# Function value obtained: 560.5247
# Current minimum: 495.5320
# Iteration No: 153 started. Searching for the next optimal point.
# ['rbf', 7.884562365616977, 0.013282325642666414, 0.09554098931780965, 2, -1.0]
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 3.6774
# Function value obtained: 560.3901
# Current minimum: 495.5320
# Iteration No: 154 started. Searching for the next optimal point.
# ['rbf', 0.8746849225744936, 0.022830255872957617, 0.04024803748287167, 3, -0.5839664439104277]
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 4.5906
# Function value obtained: 531.2656
# Current minimum: 495.5320
# Iteration No: 155 started. Searching for the next optimal point.
# ['poly', 6.221949624715435, 0.03109821436487082, 0.009903364194219808, 2, 0.22733564805138018]
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 4.9787
# Function value obtained: 623.9904
# Current minimum: 495.5320
# Iteration No: 156 started. Searching for the next optimal point.
# ['poly', 8.823792050844089, 0.030684679893589226, 0.012478538896216605, 2, 0.5762051180409797]
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 5.6945
# Function value obtained: 619.9307
# Current minimum: 495.5320
# Iteration No: 157 started. Searching for the next optimal point.
# ['poly', 10.0, 0.001, 0.013800175951116746, 2, 1.0]
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 4.1270
# Function value obtained: 615.0314
# Current minimum: 495.5320
# Iteration No: 158 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.03193567039162739, 0.0452757567289428, 3, 1.0]
# Iteration No: 158 ended. Search finished for the next optimal point.
# Time taken: 4.3903
# Function value obtained: 523.7038
# Current minimum: 495.5320
# Iteration No: 159 started. Searching for the next optimal point.
# ['poly', 0.1, 0.04540877833444655, 0.009166540472818733, 2, 1.0]
# Iteration No: 159 ended. Search finished for the next optimal point.
# Time taken: 4.6206
# Function value obtained: 618.3958
# Current minimum: 495.5320
# Iteration No: 160 started. Searching for the next optimal point.
# ['poly', 9.681424880735856, 0.08462656395054939, 0.001, 2, -0.6374733186223782]
# Iteration No: 160 ended. Search finished for the next optimal point.
# Time taken: 6.4506
# Function value obtained: 31046.2726
# Current minimum: 495.5320
# Iteration No: 161 started. Searching for the next optimal point.
# ['poly', 6.319807212434725, 0.0264026944036367, 0.022140927208889584, 2, -0.6724469076979489]
# Iteration No: 161 ended. Search finished for the next optimal point.
# Time taken: 3.4948
# Function value obtained: 655.1904
# Current minimum: 495.5320
# Iteration No: 162 started. Searching for the next optimal point.
# ['poly', 6.491777932174945, 0.04755637174880433, 0.06014164058498276, 2, -0.4835697108983037]
# Iteration No: 162 ended. Search finished for the next optimal point.
# Time taken: 5.8144
# Function value obtained: 638.0891
# Current minimum: 495.5320
# Iteration No: 163 started. Searching for the next optimal point.
# ['poly', 7.4849001258628025, 0.1, 0.001, 2, -0.29616415096125404]
# ...
# Function value obtained: 558.6151
# Current minimum: 495.5320
# Iteration No: 247 started. Searching for the next optimal point.
# ['rbf', 3.5281637138026527, 0.01730679732291946, 0.07715834195816788, 2, -0.3916927168684218]
# Iteration No: 247 ended. Search finished for the next optimal point.
# Time taken: 8.7706
# Function value obtained: 558.9534
# Current minimum: 495.5320
# Iteration No: 248 started. Searching for the next optimal point.
# ['linear', 0.8510285315550165, 0.0219300927215173, 0.039112796611513324, 2, 0.325195633623111]
# Iteration No: 248 ended. Search finished for the next optimal point.
# Time taken: 9.1207
# Function value obtained: 628.0421
# Current minimum: 495.5320
# Iteration No: 249 started. Searching for the next optimal point.
# ['poly', 1.518753488551716, 0.09398645573925624, 0.09573542439715704, 1, 1.0]
# Iteration No: 249 ended. Search finished for the next optimal point.
# Time taken: 7.4194
# Function value obtained: 628.8649
# Current minimum: 495.5320
# Iteration No: 250 started. Searching for the next optimal point.
# ['poly', 8.463411287960575, 0.049911598589866095, 0.1, 3, 0.04496084089063235]
# Iteration No: 250 ended. Search finished for the next optimal point.
# Time taken: 9.2823
# Function value obtained: 678.5783
# Current minimum: 495.5320
# Iteration No: 251 started. Searching for the next optimal point.
# ['linear', 6.683117286878441, 0.048200854903894384, 0.08810154493057636, 1, -1.0]
# Iteration No: 251 ended. Search finished for the next optimal point.
# Time taken: 8.2006
# Function value obtained: 628.0073
# Current minimum: 495.5320
# Iteration No: 252 started. Searching for the next optimal point.
# ['linear', 7.910707117181645, 0.08707896752327446, 0.09635654021943214, 1, 1.0]
# Iteration No: 252 ended. Search finished for the next optimal point.
# Time taken: 9.9199
# Function value obtained: 628.6850
# Current minimum: 495.5320
# Iteration No: 253 started. Searching for the next optimal point.
# ['linear', 8.373357465852491, 0.05019038357847057, 0.029071600825090322, 2, -1.0]
# Iteration No: 253 ended. Search finished for the next optimal point.
# Time taken: 7.9535
# Function value obtained: 628.0137
# Current minimum: 495.5320
# Iteration No: 254 started. Searching for the next optimal point.
# ['linear', 3.6268822875956994, 0.07976691399749931, 0.06110588327465165, 3, -1.0]
# Iteration No: 254 ended. Search finished for the next optimal point.
# Time taken: 8.1702
# Function value obtained: 628.4939
# Current minimum: 495.5320
# Iteration No: 255 started. Searching for the next optimal point.
# ['linear', 10.0, 0.001, 0.01805175341925318, 1, -1.0]
# Iteration No: 255 ended. Search finished for the next optimal point.
# Time taken: 9.5719
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 256 started. Searching for the next optimal point.
# ['poly', 10.0, 0.001, 0.012962536396396634, 1, -0.11147333216085231]
# Iteration No: 256 ended. Search finished for the next optimal point.
# Time taken: 8.9037
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 257 started. Searching for the next optimal point.
# ['poly', 6.230850080288658, 0.09941302717582212, 0.03797838860543557, 3, 1.0]
# Iteration No: 257 ended. Search finished for the next optimal point.
# Time taken: 7.1933
# Function value obtained: 677.8738
# Current minimum: 495.5320
# Iteration No: 258 started. Searching for the next optimal point.
# ['rbf', 3.390524152665103, 0.0508718156149281, 0.061147851305030296, 2, -1.0]
# Iteration No: 258 ended. Search finished for the next optimal point.
# Time taken: 11.3846
# Function value obtained: 560.9691
# Current minimum: 495.5320
# Iteration No: 259 started. Searching for the next optimal point.
# ['poly', 0.9812655855871488, 0.001, 0.0035196545356966174, 1, 0.44570316335155913]
# Iteration No: 259 ended. Search finished for the next optimal point.
# Time taken: 7.5422
# Function value obtained: 543.1816
# Current minimum: 495.5320
# Iteration No: 260 started. Searching for the next optimal point.
# ['poly', 9.327503880241368, 0.08783784849238015, 0.08093487853248597, 2, 1.0]
# Iteration No: 260 ended. Search finished for the next optimal point.
# Time taken: 8.3527
# Function value obtained: 633.6840
# Current minimum: 495.5320
# Iteration No: 261 started. Searching for the next optimal point.
# ['poly', 6.895262611158837, 0.052760400483946264, 0.04075553550165092, 1, -1.0]
# Iteration No: 261 ended. Search finished for the next optimal point.
# Time taken: 10.8326
# Function value obtained: 628.0068
# Current minimum: 495.5320
# Iteration No: 262 started. Searching for the next optimal point.
# ['poly', 6.279575040897353, 0.06375396945236535, 0.05787554565861557, 3, 1.0]
# Iteration No: 262 ended. Search finished for the next optimal point.
# Time taken: 9.0338
# Function value obtained: 675.9559
# Current minimum: 495.5320
# Iteration No: 263 started. Searching for the next optimal point.
# ['linear', 10.0, 0.1, 0.001, 1, -1.0]
# Iteration No: 263 ended. Search finished for the next optimal point.
# Time taken: 9.7371
# Function value obtained: 628.9948
# Current minimum: 495.5320
# Iteration No: 264 started. Searching for the next optimal point.
# ['rbf', 2.969870975634941, 0.024757081354741837, 0.027889591233618706, 1, 0.19068704154526395]
# Iteration No: 264 ended. Search finished for the next optimal point.
# Time taken: 10.5725
# Function value obtained: 557.9543
# Current minimum: 495.5320
# Iteration No: 265 started. Searching for the next optimal point.
# ['linear', 0.43956579385869365, 0.07016939289959298, 0.07735056428541459, 2, -1.0]
# Iteration No: 265 ended. Search finished for the next optimal point.
# Time taken: 8.7803
# Function value obtained: 628.3186
# Current minimum: 495.5320
# Iteration No: 266 started. Searching for the next optimal point.
# ['poly', 9.258115817513913, 0.018378470938623347, 0.0883148622721746, 3, -0.04838219243014108]
# Iteration No: 266 ended. Search finished for the next optimal point.
# Time taken: 9.1221
# Function value obtained: 675.0404
# Current minimum: 495.5320
# Iteration No: 267 started. Searching for the next optimal point.
# ['rbf', 6.494460570405629, 0.0916667677557372, 0.05400825594368968, 3, -1.0]
# Iteration No: 267 ended. Search finished for the next optimal point.
# Time taken: 8.0579
# Function value obtained: 566.5123
# Current minimum: 495.5320
# Iteration No: 268 started. Searching for the next optimal point.
# ['rbf', 4.040721384837761, 0.09518551397422596, 0.1, 3, 0.08402346915932024]
# Iteration No: 268 ended. Search finished for the next optimal point.
# Time taken: 11.3212
# Function value obtained: 566.6976
# Current minimum: 495.5320
# Iteration No: 269 started. Searching for the next optimal point.
# ['poly', 0.7318734220794034, 0.06450645399374806, 0.0927881028702699, 3, -1.0]
# Iteration No: 269 ended. Search finished for the next optimal point.
# Time taken: 9.6112
# Function value obtained: 683.0700
# Current minimum: 495.5320
# Iteration No: 270 started. Searching for the next optimal point.
# ['rbf', 8.107113359342133, 0.014257271402086338, 0.044313146234775946, 2, -1.0]
# Iteration No: 270 ended. Search finished for the next optimal point.
# Time taken: 12.1688
# Function value obtained: 560.4564
# Current minimum: 495.5320
# Iteration No: 271 started. Searching for the next optimal point.
# ['linear', 6.398151389377074, 0.011978809056732324, 0.094370435464365, 2, -1.0]
# Iteration No: 271 ended. Search finished for the next optimal point.
# Time taken: 10.4279
# Function value obtained: 628.0647
# Current minimum: 495.5320
# Iteration No: 272 started. Searching for the next optimal point.
# ['poly', 2.8489531357599187, 0.001, 0.07411420273728558, 1, 1.0]
# Iteration No: 272 ended. Search finished for the next optimal point.
# Time taken: 9.4288
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 273 started. Searching for the next optimal point.
# ['poly', 0.1799710965029575, 0.012932084725861007, 0.03392504136414775, 3, 0.06674388780757012]
# Iteration No: 273 ended. Search finished for the next optimal point.
# Time taken: 14.0301
# Function value obtained: 673.7279
# Current minimum: 495.5320
# Iteration No: 274 started. Searching for the next optimal point.
# ['poly', 9.027076421821796, 0.018334234198865165, 0.03406166851855908, 3, -1.0]
# Iteration No: 274 ended. Search finished for the next optimal point.
# Time taken: 10.9116
# Function value obtained: 681.8111
# Current minimum: 495.5320
# Iteration No: 275 started. Searching for the next optimal point.
# ['rbf', 10.0, 0.09604403815875089, 0.08705507539528597, 1, -0.07388786473582154]
# Iteration No: 275 ended. Search finished for the next optimal point.
# Time taken: 11.0331
# Function value obtained: 566.9413
# Current minimum: 495.5320
# Iteration No: 276 started. Searching for the next optimal point.
# ['rbf', 6.166321564469503, 0.05161018465899813, 0.013834612730153177, 2, -1.0]
# Iteration No: 276 ended. Search finished for the next optimal point.
# Time taken: 7.4736
# Function value obtained: 563.1454
# Current minimum: 495.5320
# Iteration No: 277 started. Searching for the next optimal point.
# ['poly', 5.017443383828618, 0.07500028095765922, 0.07672566896674583, 3, 0.1501794807784136]
# Iteration No: 277 ended. Search finished for the next optimal point.
# Time taken: 10.4524
# Function value obtained: 681.1596
# Current minimum: 495.5320
# Iteration No: 278 started. Searching for the next optimal point.
# ['poly', 2.616243763258966, 0.07966736756767359, 0.06822220022411513, 2, -0.46810560097752496]
# Iteration No: 278 ended. Search finished for the next optimal point.
# Time taken: 11.4597
# Function value obtained: 641.2653
# Current minimum: 495.5320
# Iteration No: 279 started. Searching for the next optimal point.
# ['poly', 8.182315886598792, 0.027594270763013077, 0.0723679228251171, 3, -1.0]
# Iteration No: 279 ended. Search finished for the next optimal point.
# Time taken: 10.7498
# Function value obtained: 679.3913
# Current minimum: 495.5320
# Iteration No: 280 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.05469196460939167, 0.1, 1, -0.9120937989993951]
# Iteration No: 280 ended. Search finished for the next optimal point.
# Time taken: 8.2874
# Function value obtained: 524.1497
# Current minimum: 495.5320
# Iteration No: 281 started. Searching for the next optimal point.
# ['rbf', 9.11478864353122, 0.09504576069583003, 0.09295055889901398, 3, 1.0]
# Iteration No: 281 ended. Search finished for the next optimal point.
# Time taken: 11.1184
# Function value obtained: 566.8413
# Current minimum: 495.5320
# Iteration No: 282 started. Searching for the next optimal point.
# ['poly', 3.4367506506523946, 0.001, 0.014168124164755536, 1, -0.7411289078922486]
# Iteration No: 282 ended. Search finished for the next optimal point.
# Time taken: 10.1024
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 283 started. Searching for the next optimal point.
# ['poly', 10.0, 0.0036503949447718237, 0.008813939815545496, 1, -0.013216395474809906]
# Iteration No: 283 ended. Search finished for the next optimal point.
# Time taken: 9.5914
# Function value obtained: 628.0790
# Current minimum: 495.5320
# Iteration No: 284 started. Searching for the next optimal point.
# ['poly', 0.22275091048743947, 0.044253956022385306, 0.03729483337261894, 2, -0.46043648514031155]
# Iteration No: 284 ended. Search finished for the next optimal point.
# Time taken: 13.1381
# Function value obtained: 640.5347
# Current minimum: 495.5320
# Iteration No: 285 started. Searching for the next optimal point.
# ['poly', 5.85040485538467, 0.006539197740950648, 0.005698949761341504, 1, 0.26514102005103846]
# Iteration No: 285 ended. Search finished for the next optimal point.
# Time taken: 11.7783
# Function value obtained: 628.0851
# Current minimum: 495.5320
# Iteration No: 286 started. Searching for the next optimal point.
# ['poly', 4.975160840810432, 0.06115699948393517, 0.0119083344307136, 1, -1.0]
# Iteration No: 286 ended. Search finished for the next optimal point.
# Time taken: 10.8345
# Function value obtained: 628.1204
# Current minimum: 495.5320
# Iteration No: 287 started. Searching for the next optimal point.
# ['linear', 6.9671756952028066, 0.03640930432366182, 0.038164147614612454, 2, -0.46392833953903434]
# Iteration No: 287 ended. Search finished for the next optimal point.
# Time taken: 12.1390
# Function value obtained: 628.0530
# Current minimum: 495.5320
# Iteration No: 288 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.05771549810452161, 0.0012344181884998977, 3, -0.3254718593148078]
# Iteration No: 288 ended. Search finished for the next optimal point.
# Time taken: 9.8145
# Function value obtained: 511.7311
# Current minimum: 495.5320
# Iteration No: 289 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.012609652733784907, 0.0016888851723849674, 1, -0.31505809039406474]
# Iteration No: 289 ended. Search finished for the next optimal point.
# Time taken: 13.2284
# Function value obtained: 514.6603
# Current minimum: 495.5320
# Iteration No: 290 started. Searching for the next optimal point.
# ['poly', 10.0, 0.001, 0.003570261546973106, 1, 0.6755445741280413]
# Iteration No: 290 ended. Search finished for the next optimal point.
# Time taken: 12.6295
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 291 started. Searching for the next optimal point.
# ['poly', 10.0, 0.001, 0.008452720722417744, 1, 0.781005002873929]
# Iteration No: 291 ended. Search finished for the next optimal point.
# Time taken: 8.9462
# Function value obtained: 628.0919
# Current minimum: 495.5320
# Iteration No: 292 started. Searching for the next optimal point.
# ['rbf', 0.5941999650601487, 0.008665888791822755, 0.012229027953007319, 3, -0.41906864457221205]
# Iteration No: 292 ended. Search finished for the next optimal point.
# Time taken: 8.7172
# Function value obtained: 527.0112
# Current minimum: 495.5320
# Iteration No: 293 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.09990714990681687, 0.001062432274369307, 2, -0.5326797546160242]
# Iteration No: 293 ended. Search finished for the next optimal point.
# Time taken: 12.2803
# Function value obtained: 509.8528
# Current minimum: 495.5320
# Iteration No: 294 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.0831493514965106, 0.0014136258634853418, 2, -0.2640283983673677]
# Iteration No: 294 ended. Search finished for the next optimal point.
# Time taken: 11.8171
# Function value obtained: 512.4033
# Current minimum: 495.5320
# Iteration No: 295 started. Searching for the next optimal point.
# ['poly', 9.127984112173248, 0.04054286780174427, 0.0013956049906458461, 1, 0.26089165283502314]
# Iteration No: 295 ended. Search finished for the next optimal point.
# Time taken: 14.1610
# Function value obtained: 628.0231
# Current minimum: 495.5320
# Iteration No: 296 started. Searching for the next optimal point.
# ['rbf', 1.4326319645744607, 0.05327533649200419, 0.09978077071872672, 1, -0.7607985991015859]
# Iteration No: 296 ended. Search finished for the next optimal point.
# Time taken: 11.4107
# Function value obtained: 541.4210
# Current minimum: 495.5320
# Iteration No: 297 started. Searching for the next optimal point.
# ['rbf', 8.203299831060667, 0.01287027642650496, 0.020862261993483202, 2, 0.8563555177255999]
# Iteration No: 297 ended. Search finished for the next optimal point.
# Time taken: 7.8798
# Function value obtained: 560.3607
# Current minimum: 495.5320
# Iteration No: 298 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.07820261339358094, 0.06623821342501449, 2, 0.19398189374204522]
# Iteration No: 298 ended. Search finished for the next optimal point.
# Time taken: 13.6303
# Function value obtained: 524.3813
# Current minimum: 495.5320
# Iteration No: 299 started. Searching for the next optimal point.
# ['rbf', 0.1, 0.008353769580785365, 0.002753957184700088, 2, -0.8106707721166044]
# Iteration No: 299 ended. Search finished for the next optimal point.
# Time taken: 10.2802
# Function value obtained: 518.8110
# Current minimum: 495.5320
# Iteration No: 300 started. Searching for the next optimal point.
# ['rbf', 2.979957662905914, 0.001623320853826095, 0.030168530984478387, 2, 0.8472568971970242]
# Iteration No: 300 ended. Search finished for the next optimal point.
# Time taken: 10.9408
# Function value obtained: 556.6222
# Current minimum: 495.5320
