# %%
library(tidyverse)
library(survival)
library(survminer)
library(DESeq2)

# Custom package
library(rutils)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: ggpubr
# Loading required package: S4Vectors
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
# Loading required package: IRanges
#
# Attaching package: ‘IRanges’
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
# Loading required package: GenomicRanges
# Loading required package: GenomeInfoDb
# Loading required package: SummarizedExperiment
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Loading required package: DelayedArray
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
# Loading required package: BiocParallel
#
# Attaching package: ‘DelayedArray’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
# The following objects are masked from ‘package:base’:
#
#     aperm, apply, rowsum

# %%
dirs <- rutils::get_dev_directories(dev_paths_file = "../dev_paths.txt")
projects <- c("TCGA-CESC", "TCGA-UCS", "TCGA-UCEC", "TCGA-OV")
unified_dsets <- c("unified_cervical_data", "unified_uterine_data", "unified_uterine_endometrial_data")
matrisome_list <- paste0(dirs$data_dir, "/matrisome/matrisome_hs_masterlist.tsv")

# %%
i <- 1

# %%
sig_deg_df <- read_tsv(paste0(dirs$analysis_dir, "/", unified_dsets[i], "_sig_DESeq_results_xref_matrisome.tsv"))
matrisome_sig_deg_df <- sig_deg_df %>%
    dplyr::filter(in_matrisome == TRUE)
coldata_df <- read_tsv(paste0(dirs$data_dir, "/", unified_dsets[i], "/coldata.tsv"))
matrisome_df <- rutils::load_matrisome_df(matrisome_list)
# Out:
# Parsed with column specification:
# cols(
#   geneID = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double(),
#   in_matrisome = col_logical(),
#   division = col_character(),
#   category = col_character(),
#   gene_name = col_character(),
#   synonyms = col_character(),
#   hgnc_ids = col_double(),
#   hgnc_ids_links = col_double(),
#   uniprot_ids = col_character(),
#   refseq_ids = col_character(),
#   orthology = col_character(),
#   notes = col_character()
# )
# Parsed with column specification:
# cols(
#   sample_name = col_character(),
#   condition = col_character(),
#   data_source = col_character()
# )
# Parsed with column specification:
# cols(
#   Division = col_character(),
#   Category = col_character(),
#   `Gene Symbol` = col_character(),
#   `Gene Name` = col_character(),
#   Synonyms = col_character(),
#   HGNC_IDs = col_double(),
#   `HGNC_IDs Links` = col_double(),
#   UniProt_IDs = col_character(),
#   Refseq_IDs = col_character(),
#   Orthology = col_character(),
#   Notes = col_character()
# )

# %% [markdown]
# # Load and filter survival data

# %%
# event codes defined according to survival::Surv() docs
event_code <- list("Alive" = 0, "Dead" = 1)
covariate_cols <- c("age_at_diagnosis", "bmi", "race", "ethnicity")
dep_cols <- c("vital_status", "survival_time")

survival_df <- read_tsv(paste0(dirs$data_dir, "/", unified_dsets[i], "/survival_data.tsv")) %>%
    mutate(vital_status_num = case_when(
        vital_status == "Dead" ~ event_code[["Dead"]],
        vital_status == "Alive" ~ event_code[["Alive"]]
    )) %>%
    dplyr::select(sample_name, vital_status_num, everything(), -vital_status) %>%
    dplyr::rename(vital_status = vital_status_num)
survival_cols <- colnames(survival_df)

filtered_survival_df <- survival_df %>%
    dplyr::select(one_of(c("sample_name", dep_cols, covariate_cols))) %>%
    dplyr::filter(rowSums(is.na(.)) == 0)
# Out:
# Parsed with column specification:
# cols(
#   sample_name = col_character(),
#   vital_status = col_character(),
#   survival_time = col_double(),
#   figo_stage = col_character(),
#   days_to_last_follow_up = col_double(),
#   days_to_death = col_double(),
#   age_at_diagnosis = col_double(),
#   age_at_index = col_double(),
#   height = col_double(),
#   weight = col_double(),
#   bmi = col_double(),
#   race = col_character(),
#   ethnicity = col_character()
# )

# %%
nrow(filtered_survival_df)
# proportion of samples included in final data set
nrow(filtered_survival_df) / nrow(survival_df)
# Out:
# [1] 217
# [1] 0.8378378

# %% [markdown]
# # Load, filter, and normalize count data

# %%
counts_df <- read_tsv(paste0(dirs$data_dir, "/", unified_dsets[i], "/counts.tsv")) %>%
    dplyr::rename(geneID = Hugo_Symbol) %>%
    dplyr::select(-Entrez_Gene_Id) %>%
    dplyr::mutate_if(is.numeric, round, 0) %>%
    dplyr::filter(geneID %in% matrisome_df$gene_symbol)    # Only care about matrisome genes


# Match up columns of counts with rows of survival data & only include samples present in survival data
filtered_survival_counts_df <- counts_df[, c("geneID", filtered_survival_df$sample_name)] %>%
    dplyr::filter(rowSums(.[, -1]) > 0)    # Ignore genes which are unexpressed in this group

norm_filtered_survival_counts <- varianceStabilizingTransformation(
    as.matrix(filtered_survival_counts_df[, -1])
)
rownames(norm_filtered_survival_counts) <- filtered_survival_counts_df$geneID
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Hugo_Symbol = col_character()
# )
# See spec(...) for full column specifications.
# converting counts to integer mode

# %%
# Sample-wise gene counts should match the order of samples 
all(rownames(t(norm_filtered_survival_counts)) == filtered_survival_df$sample_name)
# Out:
# [1] TRUE

# %% [markdown]
# # Combine filtered survival data and normalized count data

# %%
joined_survival_counts_df <- filtered_survival_df %>%
    inner_join(
        as_tibble(t(norm_filtered_survival_counts), rownames = "sample_name"),
        by = "sample_name"
    )

# Some genes contain the '-' symbol, which affects formulae
colnames(joined_survival_counts_df) <- gsub("-", "_", colnames(joined_survival_counts_df))

# %% [markdown]
# # Test significance of including a gene

# %%
genes_of_interest <- colnames(joined_survival_counts_df %>% dplyr::select(-colnames(filtered_survival_df)))
null_model_formula_chr <- paste0(
    "Surv(survival_time, vital_status) ~ ",
    paste(covariate_cols, collapse = " + ")
)
survival_fit_null <- coxph(
    as.formula(null_model_formula_chr),
    data = joined_survival_counts_df,
    singular.ok = TRUE
)

gene_pvals <- c()
gene_coeffs <- c()

# %%
for (g in genes_of_interest) {
    gene_model_formula_chr <- paste0(null_model_formula_chr, " + ", g)
    survival_fit_gene <- coxph(
        as.formula(gene_model_formula_chr),
        data = joined_survival_counts_df,
        singular.ok = TRUE
    )
    anova_res <- anova(survival_fit_null, survival_fit_gene, test = "LRT")
    gene_pvals <- c(gene_pvals, anova_res[["P(>|Chi|)"]][2])
    gene_coeffs <- c(gene_coeffs, survival_fit_gene$coefficients[[g]])
}
# Out:
# Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”Warning message in fitter(X, Y, istrat, offset, init, control, weights = weights, :
# “Loglik converged before variable  10 ; coefficient may be infinite. ”

# %%
# Re-sub '-' for '_' now that no longer needed for formulae
cox_regression_df <- tibble("geneID" = gsub("_", "-", genes_of_interest), "gene_pval" = gene_pvals, "gene_coeff" = gene_coeffs)
sig_cox_regression_df <- cox_regression_df %>%
    dplyr::filter(gene_pval < 0.05)

# %%
matrisome_df %>%
    dplyr::filter(gene_symbol %in% intersect(matrisome_sig_deg_df$geneID, sig_cox_regression_df$geneID))
# Out:
#    gene_symbol division             category
# 1  COLQ        Core matrisome       ECM Glycoproteins
# 2  EMILIN3     Core matrisome       ECM Glycoproteins
# 3  LAMC2       Core matrisome       ECM Glycoproteins
# 4  MATN4       Core matrisome       ECM Glycoproteins
# 5  MMRN2       Core matrisome       ECM Glycoproteins
# 6  NID1        Core matrisome       ECM Glycoproteins
# 7  NTN5        Core matrisome       ECM Glycoproteins
# 8  NTNG2       Core matrisome       ECM Glycoproteins
# 9  RELN        Core matrisome       ECM Glycoproteins
# 10 SPP1        Core matrisome       ECM Glycoproteins
# 11 TGFBI       Core matrisome       ECM Glycoproteins
# 12 ZP1         Core matrisome       ECM Glycoproteins
# 13 ZPLD1       Core matrisome       ECM Glycoproteins
# 14 COL11A1     Core matrisome       Collagens
# 15 COL12A1     Core matrisome       Collagens
# 16 COL3A1      Core matrisome       Collagens
# 17 ESM1        Core matrisome       Proteoglycans
# 18 C1QTNF4     Matrisome-associated ECM-affiliated Proteins
# 19 CLEC3B      Matrisome-associated ECM-affiliated Proteins
# 20 CLEC6A      Matrisome-associated ECM-affiliated Proteins
# 21 LGALS9      Matrisome-associated ECM-affiliated Proteins
# 22 PLXNC1      Matrisome-associated ECM-affiliated Proteins
# 23 SEMA4A      Matrisome-associated ECM-affiliated Proteins
# 24 SEMA5A      Matrisome-associated ECM-affiliated Proteins
# 25 ADAM11      Matrisome-associated ECM Regulators
# 26 CST7        Matrisome-associated ECM Regulators
# 27 HPSE        Matrisome-associated ECM Regulators
# 28 HPSE2       Matrisome-associated ECM Regulators
# 29 LOXL3       Matrisome-associated ECM Regulators
# 30 MMP1        Matrisome-associated ECM Regulators
# ⋮  ⋮           ⋮                    ⋮
# 41 ANGPTL4     Matrisome-associated Secreted Factors
# 42 BMP7        Matrisome-associated Secreted Factors
# 43 C1QTNF9B    Matrisome-associated Secreted Factors
# 44 CBLN4       Matrisome-associated Secreted Factors
# 45 CCL20       Matrisome-associated Secreted Factors
# 46 CCL22       Matrisome-associated Secreted Factors
# 47 CCL25       Matrisome-associated Secreted Factors
# 48 CCL7        Matrisome-associated Secreted Factors
# 49 CSF2        Matrisome-associated Secreted Factors
# 50 CXCL2       Matrisome-associated Secreted Factors
# 51 CXCL3       Matrisome-associated Secreted Factors
# 52 CXCL5       Matrisome-associated Secreted Factors
# 53 EREG        Matrisome-associated Secreted Factors
# 54 FGF17       Matrisome-associated Secreted Factors
# 55 FIGF        Matrisome-associated Secreted Factors
# 56 FRZB        Matrisome-associated Secreted Factors
# 57 FSTL3       Matrisome-associated Secreted Factors
# 58 GDF7        Matrisome-associated Secreted Factors
# 59 HRNR        Matrisome-associated Secreted Factors
# 60 IL12A       Matrisome-associated Secreted Factors
# 61 IL16        Matrisome-associated Secreted Factors
# 62 IL1A        Matrisome-associated Secreted Factors
# 63 IL1B        Matrisome-associated Secreted Factors
# 64 INHBA       Matrisome-associated Secreted Factors
# 65 INSL3       Matrisome-associated Secreted Factors
# 66 OSM         Matrisome-associated Secreted Factors
# 67 RPTN        Matrisome-associated Secreted Factors
# 68 SCUBE1      Matrisome-associated Secreted Factors
# 69 SCUBE2      Matrisome-associated Secreted Factors
# 70 WNT3A       Matrisome-associated Secreted Factors
#    gene_name
# 1  collagen-like tail subunit (single strand of homotrimer) of asymmetric acetylcholinesterase
# 2  elastin microfibril interfacer 3
# 3  laminin, gamma 2
# 4  matrilin 4
# 5  multimerin 2
# 6  nidogen 1
# 7  netrin 5
# 8  netrin G2
# 9  reelin
# 10 secreted phosphoprotein 1
# 11 transforming growth factor, beta-induced, 68kDa
# 12 zona pellucida glycoprotein 1 (sperm receptor)
# 13 zona pellucida-like domain containing 1
# 14 collagen, type XI, alpha 1
# 15 collagen, type XII, alpha 1
# 16 collagen, type III, alpha 1
# 17 endothelial cell-specific molecule 1
# 18 C1q and tumor necrosis factor related protein 4
# 19 C-type lectin domain family 3, member B
# 20 C-type lectin domain family 6, member A
# 21 lectin, galactoside-binding, soluble, 9
# 22 plexin C1
# 23 sema domain, immunoglobulin domain (Ig), transmembrane domain (TM) and short cytoplasmic domain, (semaphorin) 4A
# 24 sema domain, seven thrombospondin repeats (type 1 and type 1-like), transmembrane domain (TM) and short cytoplasmic domain, (semaphorin) 5A
# 25 ADAM metallopeptidase domain 11
# 26 cystatin F (leukocystatin)
# 27 heparanase
# 28 heparanase 2
# 29 lysyl oxidase-like 3
# 30 matrix metallopeptidase 1 (interstitial collagenase)
# ⋮  ⋮
# 41 angiopoietin-like 4
# 42 bone morphogenetic protein 7
# 43 C1q and tumor necrosis factor related protein 9B
# 44 cerebellin 4 precursor
# 45 chemokine (C-C motif) ligand 20
# 46 chemokine (C-C motif) ligand 22
# 47 chemokine (C-C motif) ligand 25
# 48 chemokine (C-C motif) ligand 7
# 49 colony stimulating factor 2 (granulocyte-macrophage)
# 50 chemokine (C-X-C motif) ligand 2
# 51 chemokine (C-X-C motif) ligand 3
# 52 chemokine (C-X-C motif) ligand 5
# 53 epiregulin
# 54 fibroblast growth factor 17
# 55 c-fos induced growth factor (vascular endothelial growth factor D)
# 56 frizzled-related protein
# 57 follistatin-like 3 (secreted glycoprotein)
# 58 growth differentiation factor 7
# 59 hornerin
# 60 interleukin 12A (natural killer cell stimulatory factor 1, cytotoxic lymphocyte maturation factor 1, p35)
# 61 interleukin 16 (lymphocyte chemoattractant factor)
# 62 interleukin 1, alpha
# 63 interleukin 1, beta
# 64 inhibin, beta A
# 65 insulin-like 3 (Leydig cell)
# 66 oncostatin M
# 67 repetin
# 68 signal peptide, CUB domain, EGF-like 1
# 69 signal peptide, CUB domain, EGF-like 2
# 70 wingless-type MMTV integration site family, member 3A
#    synonyms                                           hgnc_ids hgnc_ids_links
# 1  EAD|FLJ55041                                        2226     2226
# 2  C20orf130|DKFZp434A2410|EMILIN5|dJ620E11.4         16123    16123
# 3  B2T|BM600|CSF|EBR2|EBR2A|LAMB2T|LAMNB2|MGC138491|M  6493     6493
# 4  FLJ14417|HE6WCR54                                   6910     6910
# 5  EMILIN3|EndoGlyx-1|FLJ13465                        19888    19888
# 6  NID                                                 7821     7821
# 7  -                                                  25208    25208
# 8  KIAA0625|KIAA1857|LHLL9381|Lmnt2|MGC21884|NTNG1|bA 14288    14288
# 9  PRO1598|RL                                          9957     9957
# 10 BNSP|BSPI|ETA-1|MGC110940|OPN                      11255    11255
# 11 BIGH3|CDB1|CDG2|CDGG1|CSD|CSD1|CSD2|CSD3|EBMD|LCD1 11771    11771
# 12 MGC87693                                           13187    13187
# 13 -                                                  27022    27022
# 14 CO11A1|COLL6|STL2                                   2186     2186
# 15 BA209D8.1|COL12A1L|DJ234P15.1                       2188     2188
# 16 EDS4A|FLJ34534                                      2201     2201
# 17 endocan                                             3466     3466
# 18 CTRP4|ZACRP4                                       14346    14346
# 19 DKFZp686H17246|TN|TNA                              11891    11891
# 20 CLECSF10|dectin-2                                  14556    14556
# 21 HUAT|LGALS9A|MGC117375|MGC125973|MGC125974          6570     6570
# 22 CD232|PLXN-C1|VESPR                                 9106     9106
# 23 CORD10|FLJ12287|RP35|SEMAB|SEMB                    10729    10729
# 24 FLJ12815|SEMAF|semF                                10736    10736
# 25 MDC                                                  189      189
# 26 CMAP                                                2479     2479
# 27 HPA|HPR1|HPSE1|HSE1                                 5164     5164
# 28 FLJ11684|FLJ44022|HPA2|HPR2|MGC133234              18374    18374
# 29 LOXL                                               13869    13869
# 30 CLG|CLGN                                            7155     7155
# ⋮  ⋮                                                  ⋮        ⋮
# 41 ANGPTL2|ARP4|FIAF|HFARP|NL2|PGAR|pp1158            16039    16039
# 42 OP-1                                                1074     1074
# 43 RP11-45B20.2|CTRP9B|MGC117159                      34072    34072
# 44 CBLNL1                                             16231    16231
# 45 CKb4|LARC|MIP-3a|MIP3A|SCYA20|ST38                 10619    10619
# 46 A-152E5.1|ABCD-1|DC/B-CK|MDC|MGC34554|SCYA22|STCP- 10621    10621
# 47 Ckb15|MGC150327|SCYA25|TECK                        10624    10624
# 48 FIC|MARC|MCP-3|MCP3|MGC138463|MGC138465|NC28|SCYA6 10634    10634
# 49 GMCSF|MGC131935|MGC138897                           2434     2434
# 50 CINC-2a|GRO2|GROb|MGSA-b|MIP-2a|MIP2|MIP2A|SCYB2    4603     4603
# 51 CINC-2b|GRO3|GROg|MIP-2b|MIP2B|SCYB3                4604     4604
# 52 ENA-78|SCYB5                                       10642    10642
# 53 ER                                                  3443     3443
# 54 FGF-13                                              3673     3673
# 55 VEGF-D|VEGFD                                        3708     3708
# 56 FRE|FRITZ|FRP-3|FRZB-1|FRZB-PEN|FRZB1|FZRB|OS1|SFR  3959     3959
# 57 FLRG|FSRP                                           3973     3973
# 58 BMP12                                               4222     4222
# 59 S100A16|S100a18                                    20846    20846
# 60 CLMF|IL-12A|NFSK|NKSF1|P35                          5969     5969
# 61 FLJ16806|FLJ42735|FLJ44234|LCF|NIL16|PRIL16|prIL-1  5980     5980
# 62 IL-1A|IL1|IL1-ALPHA|IL1F1                           5991     5991
# 63 IL-1|IL1-BETA|IL1F2                                 5992     5992
# 64 EDF|FRP                                             6066     6066
# 65 MGC119818|MGC119819|RLF|RLNL                        6086     6086
# 66 MGC20461                                            8506     8506
# 67 FLJ39117                                           26809    26809
# 68 -                                                  13441    13441
# 69 CEGB1|CEGF1|CEGP1|FLJ16792|FLJ35234|MGC133057      30425    30425
# 70 MGC119418|MGC119419|MGC119420                      15983    15983
#    uniprot_ids
# 1  C9JBB2:F8WA67:Q9Y215:S4R408
# 2  Q9NT22
# 3  Q13753
# 4  A6NNA4:O95460
# 5  Q9H8L6:R4GMY6:V9GY37:V9GY43:V9GYS9
# 6  P14543
# 7  M0QXZ9:Q8WTR8
# 8  A6NMX7:Q5JUJ3:Q96CW9
# 9  H7C2B0:J3KQ66:P78509
# 10 D6R9C5:P10451
# 11 D6RBX4:G8JLA8:H0Y8L3:H0Y8M8:H0Y9D7:H0YAB8:H0YAH8:Q15582:S4R3C6
# 12 H0YG11:P60852
# 13 Q8TCW7
# 14 C9JMN2:H7C381:P12107
# 15 D6RGG3:H0Y4P7:H0Y5N9:H0Y991:Q99715
# 16 E7ENY8:H7C435:P02461
# 17 M0R154:Q9NQ30
# 18 E9PPZ5:Q9BXJ3
# 19 E9PHK0:P05452
# 20 Q6EIG7
# 21 B4DWP7:F8W9W4:J3KS82:J3KSA0:J3QKK6:J3QS92:K7EPS0:O00182:Q8WYQ7
# 22 B4DHQ7:F5H3A2:F8VUW4:F8W095:F8W1K6:O60486
# 23 Q5TCI4:Q5TCI6:Q5TCJ5:Q5TCJ7:Q9H3S1
# 24 D6R9K6:D6RAF4:H0Y9H9:Q13591
# 25 B4DKD2:H7BY08:K7EKA8:O75078
# 26 O76096
# 27 D6RAQ1:D6RHG4:Q9Y251
# 28 Q8WWQ2
# 29 B8ZZT6:B9A025:C9J5M1:E7END4:H7C248:P58215
# 30 P03956
# ⋮  ⋮
# 41 M0QZ51:M0R0N8:M0R2X8:M0R369:M0R3A2:Q9BY76
# 42 B1AKZ9:B1AL00:H0Y4B5:P18075
# 43 B2RNN3
# 44 Q9NTU7
# 45 P78556
# 46 O00626
# 47 C9JDZ7:O15444
# 48 A8MVH1:A8MX17:P80098:Q7Z7Q8
# 49 P04141
# 50 P19875
# 51 P19876
# 52 P42830
# 53 O14944
# 54 O60258
# 55 O43915
# 56 Q92765
# 57 K7EM71:K7ES54:O95633
# 58 Q7Z4P5
# 59 Q86YZ3
# 60 E7ENE1:E9PGR3:P29459
# 61 H0YKB7:H0YLB1:H0YLH9:H0YLL1:H3BN12:H3BT15:H3BVH5:Q14005
# 62 P01583
# 63 C9JSC2:C9JVK0:C9JWV2:P01584
# 64 P08476
# 65 M0QXQ3:P51460
# 66 B5MC70:B5MCX1:P13725
# 67 Q6XPR3
# 68 B1AH90:H0Y4Y9:Q8IWY4
# 69 E7EQD6:H0YD28:H0YDN3:H0YEB3:H0YEI5:Q9NQ36
# 70 P56704
#    refseq_ids
# 1  NP_005668.2:NP_536799.1:NP_536800.2
# 2  NP_443078.1
# 3  NP_005553.2:NP_061486.2
# 4  NP_085080.1:NP_085095.1:XP_005260654.1:NP_085095.1
# 5  NP_079032.2
# 6  NP_002499.2
# 7  NP_665806.1:XP_006723074.1
# 8  NP_115925.2
# 9  NP_005036.2:NP_774959.1
# 10 NP_000573.1:NP_001035147.1:NP_001035149.1:NP_001238758.1:NP_001238759.1
# 11 NP_000349.1
# 12 NP_997224.2
# 13 NP_778226.1:XP_005247167.1
# 14 NP_001177638.1:NP_001845.3:NP_542196.2:NP_542197.3
# 15 NP_004361.3:NP_542376.2
# 16 NP_000081.1
# 17 NP_001129076.1:NP_008967.1
# 18 NP_114115.2
# 19 NP_003269.2:XP_005265483.1
# 20 NP_001007034.1
# 21 NP_002299.2:NP_033665.1:XP_006721955.1:XP_006721957.1
# 22 NP_005752.1
# 23 NP_001180229.1:NP_001180230.1:NP_001180231.1:NP_071762.2
# 24 NP_003957.2:XP_006714569.1:XP_006714570.1
# 25 NP_002381.2
# 26 NP_003641.3
# 27 NP_001092010.1:NP_001159970.1:NP_001186759.1:NP_006656.2
# 28 NP_001159716.1:NP_001159717.1:NP_001159718.1:NP_068600.4
# 29 NP_001276093.1:NP_001276094.1:NP_115992.1
# 30 NP_002412.1
# ⋮  ⋮
# 41 NP_001034756.1:NP_647475.1
# 42 NP_001710.1
# 43 NP_001007538.1
# 44 NP_542184.1
# 45 NP_001123518.1:NP_004582.1
# 46 NP_002981.2
# 47 NP_001188288.1:NP_005615.2
# 48 NP_006264.2
# 49 NP_000749.2
# 50 NP_002080.1
# 51 NP_002081.2
# 52 NP_002985.1
# 53 NP_001423.1
# 54 NP_003858.1:XP_005273733.1
# 55 NP_004460.1
# 56 NP_001454.2
# 57 NP_005851.1
# 58 NP_878248.2
# 59 NP_001009931.1
# 60 NP_000873.2:XP_005247492.1
# 61 NP_001165599.1:NP_004504.3:NP_757366.2:XP_005254403.1
# 62 NP_000566.3
# 63 NP_000567.1
# 64 NP_002183.1
# 65 NP_001252516.1:NP_005534.2
# 66 NP_065391.1
# 67 NP_001116437.1
# 68 NP_766638.2
# 69 NP_001164161.1:NP_066025.2:XP_005253090.2
# 70 NP_149122.1
#    orthology                notes
# 1  Mouse:Colq|              Basement Membrane
# 2  Mouse:Emilin3|           NA
# 3  Mouse:Lamc2|             Laminin, Basement Membrane
# 4  Mouse:Matn4|             NA
# 5  Mouse:Mmrn2|             NA
# 6  Mouse:Nid1|              Basement Membrane
# 7  Mouse:Ntn5|              NA
# 8  Mouse:Ntng2|             NA
# 9  Mouse:Reln|              NA
# 10 Mouse:Spp1|              NA
# 11 Mouse:Tgfbi|             NA
# 12 Mouse:Zp1|               NA
# 13 Mouse:Zpld1|             NA
# 14 Mouse:Col11a1|           NA
# 15 Mouse:Col12a1|           FACIT
# 16 Mouse:Col3a1|            NA
# 17 Mouse:Esm1|              NA
# 18 Mouse:C1qtnf4|           NA
# 19 Mouse:Clec3b|            NA
# 20 Mouse:Clec4n|            NA
# 21 Mouse:Lgals9|            Galectin
# 22 Mouse:Plxnc1|            Plexin
# 23 Mouse:Sema4a|            Semaphorin
# 24 Mouse:Sema5a|            Semaphorin
# 25 Mouse:Adam11|            NA
# 26 Mouse:Cst7|              Cystatin
# 27 Mouse:Hpse|              NA
# 28 Mouse:Hpse2|             NA
# 29 Mouse:Loxl3|             NA
# 30 Mouse:Mmp1a|Mouse:Mmp1b| NA
# ⋮  ⋮                        ⋮
# 41 Mouse:Angptl4|           NA
# 42 Mouse:Bmp7|              NA
# 43 NA                       NA
# 44 Mouse:Cbln4|             NA
# 45 Mouse:Ccl20|             NA
# 46 Mouse:Ccl22|             NA
# 47 Mouse:Ccl25|             NA
# 48 Mouse:Ccl7|              NA
# 49 Mouse:Csf2|              NA
# 50 Mouse:Cxcl2|             NA
# 51 Mouse:Cxcl3|             NA
# 52 Mouse:Cxcl5|             NA
# 53 Mouse:Ereg|              NA
# 54 Mouse:Fgf17|             NA
# 55 Mouse:Figf|              NA
# 56 Mouse:Frzb|              NA
# 57 Mouse:Fstl3|             NA
# 58 Mouse:Gdf7|              NA
# 59 Mouse:Hrnr|              NA
# 60 Mouse:Il12a|             NA
# 61 Mouse:Il16|              NA
# 62 Mouse:Il1a|              NA
# 63 Mouse:Il1b|              NA
# 64 Mouse:Inhba|             NA
# 65 Mouse:Insl3|             NA
# 66 Mouse:Osm|               NA
# 67 Mouse:Rptn|              NA
# 68 Mouse:Scube1|            NA
# 69 Mouse:Scube2|            NA
# 70 Mouse:Wnt3a|             NA
